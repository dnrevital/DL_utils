# %%
import matplotlib.pyplot as plt

# %%
vals = [0.25840998,
        0.3683616, 
        0.29128656, 
        0.015636504, 
        0.38397288,
        0.494873,
        0.18626231,
        0.46476555,
        0.0839656]

# %%
plt.hist(vals, bins = 5)
plt.show()
