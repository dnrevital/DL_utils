# %% [markdown]
# ## Imports

# %%
import cv2
import os
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ## Load Images Utility

# %%
def load_images_from_folder(folder):
    imnames = []
    images = []
    for imname in os.listdir(folder):
        #imrgb = cv2.imread(os.path.join(folder,imname))
        im = cv2.imread(os.path.join(folder,imname))
        #im = cv2.cvtColor(imrgb, cv2.COLOR_BGR2GRAY)        
        if im is not None:
            imnames.append(imname)
            images.append(im)
    return imnames, images

# %% [markdown]
# ## Load & Process Loop

# %%
folder='/home/drevital/obstacles_classification_datasets/rgb_6/to_reverse'
out_folder = '/home/drevital/obstacles_classification_datasets/rgb_6/reversed'
imnames, images = load_images_from_folder(folder)

for imname in imnames:
    im = images[imnames.index(imname)]
    w = im.shape[1]
    im1 = im[:,:w//2]
    im2 = im[:,w//2:]    
    reverse = cv2.hconcat([im2, im1])
    outname = imname.split('.')[0] + '_reversed.jpg'
    outpath = os.path.join(out_folder, outname)
    cv2.imwrite(outpath, reverse)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-6fecff2a6d6b> in <module>
#       1 folder='/home/drevital/obstacles_classification_datasets/rgb_6/to_reverse'
#       2 out_folder = '/home/drevital/obstacles_classification_datasets/rgb_6/reversed'
# ----> 3 imnames, images = load_images_from_folder(folder)
#       4
#       5 for imname in imnames:
#
# <ipython-input-2-4ca050b7835a> in load_images_from_folder(folder)
#       5         imrgb = cv2.imread(os.path.join(folder,imname))
#       6         #im = cv2.cvtColor(imrgb, cv2.COLOR_BGR2GRAY)
# ----> 7         if im is not None:
#       8             imnames.append(imname)
#       9             images.append(im)
#
# NameError: name 'im' is not defined

# %% [markdown]
# ## Read Original Image

# %%
'''
im = images[imnames.index(imname)]
w = im.shape[1]
im1 = im[:,:w//2]
im2 = im[:,w//2:]
'''

# %% [markdown]
# ## Display Original Image

# %%
'''
plt.imshow(im, cmap='gray', vmin=0, vmax=255)
plt.title('im')
plt.show()

plt.imshow(im1, cmap='gray', vmin=0, vmax=255)
plt.title('im1')
plt.show()

plt.imshow(im2, cmap='gray', vmin=0, vmax=255)
plt.title('im2')
plt.show()
'''

# %% [markdown]
# ## Reverse Pair Images Order

# %%
'''
reverse = cv2.hconcat([im2, im1])
'''

# %% [markdown]
# ## Display Reversed Image-Pair

# %%
'''
plt.imshow(reverse, cmap='gray', vmin=0, vmax=255)
plt.title('reversed')
plt.show()
'''

# %% [markdown]
# ## Store Reversed Image_pair

# %%
'''
outname = imname.split('.')[0] + '_reversed.jpg'
outpath = os.path.join(folder, outname)
cv2.imwrite(outpath, reverse)
'''
