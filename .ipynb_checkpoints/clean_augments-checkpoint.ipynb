# %% [markdown]
# ## Imports

# %%
import os
import shutil

# %% [markdown]
# ## Settings

# %%
augmented_dir = '/home/drevital/obstacles_classification_datasets/gg_2_channels/no_obstacle_pairs'
dst_dir = '/home/drevital/obstacles_classification_datasets/rgb_6/annotated/no_obstacle'
augmentation_infixes = ['_rotate_',
                        '_noise_',
                        '_crop_',
                        '_shear_',
                        '_contrast_',
                        '_flip_vr_',
                        '_flip_hr_']
