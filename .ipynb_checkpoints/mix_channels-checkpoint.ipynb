# %% [markdown]
# ## Imports

# %%
import os
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %% [markdown]
# ## Settings

# %%
R = 255
G = 128
B = 64
height = 180
width = 320
mix_dir = '/home/drevital/obstacles_classification_datasets/test_mix'

# %% [markdown]
# ## Define Mixed Channels Augments

# %%
r = 0
g = 1
b = 2

augments = {0: [r, b, g],
            1: [g, r, b],
            2: [g, b, r],
            3: [b, r, g],
            4: [b, g, r]}

# %% [markdown]
# ## Build Source Image

# %%
src = [[[R, G, B] for j in range(width)] for i in range(height)]
src = np.array(src)
plt.imshow(src)
plt.title('src')
plt.show()
src[0][:5]
# Out:
# array([[255, 128,  64],
#        [255, 128,  64],
#        [255, 128,  64],
#        [255, 128,  64],
#        [255, 128,  64]])

# %% [markdown]
# ## Build & Display Augmentations

# %%
#aug = [[[src[i][j][augments[0][a]] for a in range(3)] for j in range(width)] for i in range(height)]

# %%
for a in range(5):
    aug = [[[src[i][j][augments[a][k]] for k in range(3)]
            for j in range(width)] for i in range(height)]
    aug = np.array(aug)
    plt.imshow(aug)
    plt.title(f'augment {a}')
    plt.show()
    print(aug[0][:5])
# Out:
# [[255  64 128]
#  [255  64 128]
#  [255  64 128]
#  [255  64 128]
#  [255  64 128]]
# [[128 255  64]
#  [128 255  64]
#  [128 255  64]
#  [128 255  64]
#  [128 255  64]]
# [[128  64 255]
#  [128  64 255]
#  [128  64 255]
#  [128  64 255]
#  [128  64 255]]
# [[ 64 255 128]
#  [ 64 255 128]
#  [ 64 255 128]
#  [ 64 255 128]
#  [ 64 255 128]]
# [[ 64 128 255]
#  [ 64 128 255]
#  [ 64 128 255]
#  [ 64 128 255]
#  [ 64 128 255]]

# %% [markdown]
# ## Store SRC & Mixed images

# %%
#impath = os.path.join(mix_dir, 'src')
#cv2.imwrite(impath, src)
