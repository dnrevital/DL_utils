# %%
import ipywidgets as widgets
from IPython.display import display
import cv2
import io
import boto3

# %%
widgets.IntSlider()
# Out:
# IntSlider(value=0)

# %%
s = widgets.IntSlider()
display(s)
# Out:
# IntSlider(value=0)

# %%
display(s)
# Out:
# IntSlider(value=0)

# %%
s.value
# Out:
# 50

# %%
s.keys
# Out:
# ['_dom_classes',
#  '_model_module',
#  '_model_module_version',
#  '_model_name',
#  '_view_count',
#  '_view_module',
#  '_view_module_version',
#  '_view_name',
#  'continuous_update',
#  'description',
#  'description_tooltip',
#  'disabled',
#  'layout',
#  'max',
#  'min',
#  'orientation',
#  'readout',
#  'readout_format',
#  'step',
#  'style',
#  'value']

# %%
widgets.Text(value='Hello World!', disabled=True)
# Out:
# Text(value='Hello World!', disabled=True)

# %%
a = widgets.FloatText()
b = widgets.FloatSlider()
display(a,b)

mylink = widgets.jslink((a, 'value'), (b, 'value'))

# to unlink use mylink.unlink()
# Out:
# FloatText(value=0.0)
# FloatSlider(value=0.0)

# %%
t = widgets.ToggleButton(value=True)
display(t)
# Out:
# ToggleButton(value=True)

# %%
c = widgets.Checkbox()
display(c)
# Out:
# Checkbox(value=False)

# %%
v = widgets.Valid()
display(v)
# Out:
# Valid(value=False)

# %%
my_widgets = []
my_widgets.append(widgets.Dropdown(options=['1', '2', '3']))
my_widgets.append(widgets.Dropdown(options=[('One', '1'), ('Two', '2'), ('Three', '3')]))
my_widgets.append(widgets.RadioButtons(options=['Obstacle', 'No Obstacle', 'Static', 'Removed']))
my_widgets.append(widgets.Select(options=['Obstacle', 'No Obstacle', 'Static', 'Removed']))
my_widgets.append(widgets.ToggleButtons(options=['Obstacle', 'No Obstacle', 'Static', 'Removed']))

display(*my_widgets)
# Out:
# Dropdown(options=('1', '2', '3'), value='1')
# Dropdown(options=(('One', '1'), ('Two', '2'), ('Three', '3')), value='1')
# RadioButtons(options=('Obstacle', 'No Obstacle', 'Static', 'Removed'), value='Obstacle')
# Select(options=('Obstacle', 'No Obstacle', 'Static', 'Removed'), value='Obstacle')
# ToggleButtons(options=('Obstacle', 'No Obstacle', 'Static', 'Removed'), value='Obstacle')

# %%
tog = widgets.ToggleButtons(options=['Obstacle', 'No Obstacle', 'Static', 'Removed'])
output = widgets.Output()
display(tog, output)

def annotate(change):
    with output:
        print(change['new'])
        
tog.observe(annotate, names='value')
# Out:
# ToggleButtons(options=('Obstacle', 'No Obstacle', 'Static', 'Removed'), value='Obstacle')
# Output()

# %%
client = boto3.client("s3")
bucket='obstacles-classification'
key= 'new_factory/obstacle/obs_106_1247.jpg'
outfile = io.BytesIO()
client.download_fileobj(bucket, key, outfile)
outfile.seek(0)
im = plt.imread(outfile, format='jpg')
plt.imshow(im, cmap='gray', vmin=0, vmax=255)
plt.show()
