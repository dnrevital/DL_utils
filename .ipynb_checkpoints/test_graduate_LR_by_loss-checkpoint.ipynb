# %%
class LRDecayCallback():
    def __init__(self):
        self.min_lr = 5e-6
        self.max_lr = 5e-5
        self.min_loss = 0.85
        self.max_loss = 37.5
        self.loss_range = max_loss - min_loss
        self.lr_range - max_lr - min_lr
        
    def on_epoch_end(self, val_loss):
        f = (val_loss - self.min_loss) / self.loss_range
        lr = self.min_lr + f * self.lr_range
        print(f'LR: {lr}')

# %%
lr = 0.00005

for epoch in range(1, 11):
    print(f'epoch: {epoch}, learning rate: {step_decay(epoch, lr):.8f}')
