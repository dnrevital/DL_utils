# %% [markdown]
# ## Imports

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Model

# %%
# !ls /home/drevital/cs_video_processor/models/jan23_d_20_15_bm_1_chp_30
# Out:
# ls: cannot access '/home/drevital/cs_video_processor/models/jan23_d_20_15_bm_1_chp_30': No such file or directory

# %%
# !ls /home/drevital/cs_video_processor/models/jan23_d_20_15*
# Out:
# /home/drevital/cs_video_processor/models/jan23_d_20_15:
# assets	saved_model.pb	variables
#
# /home/drevital/cs_video_processor/models/jan23_d_20_15_bm_1:
# assets	saved_model.pb	variables

# %% [markdown]
# ## Load model from checkpoint

# %%
model_path = '/home/drevital/cs_video_processor/models/jan23_d_20_15_bm_1_chp_30'
model = tf.keras.models.load_model(model_path)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-6-2d204c8f5a18> in <module>
#       1 model_path = '/home/drevital/cs_video_processor/models/jan23_d_20_15_bm_1_chp_30'
# ----> 2 model = tf.keras.models.load_model(model_path)
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/saving/save.py in load_model(filepath, custom_objects, compile, options)
#     204         filepath = path_to_string(filepath)
#     205         if isinstance(filepath, str):
# --> 206           return saved_model_load.load(filepath, compile, options)
#     207
#     208   raise IOError(
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/saving/saved_model/load.py in load(path, compile, options)
#     119   # Look for metadata file or parse the SavedModel
#     120   metadata = saved_metadata_pb2.SavedMetadata()
# ...
