# %%
# !pip install pydot
# Out:
# Requirement already satisfied: pydot in /home/drevital/anaconda3/lib/python3.7/site-packages (1.4.2)
# Requirement already satisfied: pyparsing>=2.1.4 in /home/drevital/anaconda3/lib/python3.7/site-packages (from pydot) (2.4.6)
# WARNING: You are using pip version 21.1.2; however, version 21.3.1 is available.
# You should consider upgrading via the '/home/drevital/anaconda3/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# ## Imports

# %%
import tensorflow as tf

# %% [markdown]
# ## Settings

# %%
model_path = '/home/drevital/cs_video_processor/models/7_channels'
plot_path = '/home/drevital/model_plots/7_channels.png'

# %% [markdown]
# ## Load Model

# %%
model = tf.keras.models.load_model(model_path)
# Out:
# WARNING:tensorflow:SavedModel saved prior to TF 2.5 detected when loading Keras model. Please ensure that you are saving the model with model.save() or tf.keras.models.save_model(), *NOT* tf.saved_model.save(). To confirm, there should be a file named "keras_metadata.pb" in the SavedModel directory.

# %% [markdown]
# ## Plot Model

# %%
tf.keras.utils.plot_model(model,
                          to_file=plot_path,
                          show_shapes=True,
                          show_layer_names=True)
