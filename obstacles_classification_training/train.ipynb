# %%
import time

train_dataset_name = 'nov22_c_2__1_0'
eval_dataset_name = 'nov22_c_2__1_0'
dataset_hyphened_name = train_dataset_name.replace('_', '-') + '-hflip-mix-0-2-' + f'{time.strftime("%Y-%m-%d-%H-%M-%S", time.gmtime())}'
layers = 5

# %% [markdown]
# ### Client & SM sessions

# %%
import sagemaker, boto3

sess = boto3.Session()
sm   = sess.client('sagemaker')
role = sagemaker.get_execution_role()
sagemaker_session = sagemaker.Session(boto_session=sess)

# %% [markdown]
# ### Create experiment

# %%
from smexperiments.experiment import Experiment
from smexperiments.trial import Trial
from smexperiments.trial_component import TrialComponent

training_experiment = Experiment.create(experiment_name = f'{dataset_hyphened_name}', 
                                        description     = f'{dataset_hyphened_name}', 
                                        sagemaker_boto_client=sm)

# %% [markdown]
# ### Create trial

# %%
training_trial = Trial.create(trial_name = f'{dataset_hyphened_name}', 
                              experiment_name = training_experiment.experiment_name,
                              sagemaker_boto_client = sm,)
training_trial_comp_name = f'{dataset_hyphened_name}'
experiment_config = {"ExperimentName": training_experiment.experiment_name, 
                       "TrialName": training_trial.trial_name,
                       "TrialComponentDisplayName": training_trial_comp_name}

# %% [markdown]
# ### Run training job & visualize results

# %%
from sagemaker.tensorflow import TensorFlow

dataframe_dir = f's3://obstacles-classification/{train_dataset_name}'

hyperparams={'epochs'       : 30,
             'learning-rate': 0.00005,
             'batch-size'   : 32,
             'optimizer'    : 'adam',
             'dataframe_dir': dataframe_dir
            }

bucket_name = sagemaker_session.default_bucket()
output_path = f's3://{bucket_name}/obstacles_classification/jobs/{train_dataset_name}'

metric_definitions = [
    {'Name': 'auc', 'Regex': 'auc: ([0-9\\.]+)'},
    {'Name': 'recall', 'Regex': 'recall: ([0-9\\.]+)'},
    {'Name': 'specifity', 'Regex': 'specifity: ([0-9\\.]+)'},
    {'Name': 'accuracy', 'Regex': 'accuracy: ([0-9\\.]+)'},
    {'Name': 'loss', 'Regex': 'loss: ([0-9\\.]+)'},
    {'Name': 'validation auc', 'Regex': 'val_auc: ([0-9\\.]+)'},
    {'Name': 'validation recall', 'Regex': 'val_recall: ([0-9\\.]+)'},
    {'Name': 'validation specifity', 'Regex': 'val_specifity: ([0-9\\.]+)'},
    {'Name': 'validation accuracy', 'Regex': 'val_categorical_accuracy: ([0-9\\.]+)'},
    {'Name': 'validation loss', 'Regex': 'val_loss: ([0-9\\.]+)'},
    {'Name': 'test auc', 'Regex': 'test_auc: ([0-9\\.]+)'},
    {'Name': 'test recall', 'Regex': 'test_recall: ([0-9\\.]+)'},
    {'Name': 'test specifity', 'Regex': 'test_specifity: ([0-9\\.]+)'},
    {'Name': 'test accuracy', 'Regex': 'test_accuracy: ([0-9\\.]+)'},
    {'Name': 'test loss', 'Regex': 'test_loss: ([0-9\\.]+)'},
    {'Name': 'epoch', 'Regex': 'Epoch ([0-9]+)'},
]

tf_estimator = TensorFlow(entry_point          = 'train.py',
                          #entry_point          = '7_channels_weights_custom_preprocess.py',
                          output_path          = f'{output_path}/',
                          code_location        = output_path,
                          role                 = role,
                          train_instance_count = 1, 
                          train_instance_type  = 'ml.c5.xlarge',
                          framework_version    = '2.3', 
                          py_version           = 'py37',
                          script_mode          = True,
                          metric_definitions   = metric_definitions,
                          debugger_hook_config = False,
                          sagemaker_session    = sagemaker_session,
                          hyperparameters      = hyperparams)

job_name=f'obstacles-classification-{time.strftime("%Y-%m-%d-%H-%M-%S", time.gmtime())}'
training_dataset = f's3://obstacles-classification/{train_dataset_name}/train'
eval_dataset = f's3://obstacles-classification/{train_dataset_name}/eval'
tf_estimator.fit({'training'  : training_dataset,
                  'validation': training_dataset,
                  'eval'      : eval_dataset},   
                  job_name = job_name,
                  experiment_config=experiment_config)
# Out:
# WARNING:sagemaker.deprecations:train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# WARNING:sagemaker.deprecations:train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# WARNING:sagemaker.deprecations:train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# INFO:sagemaker.image_uris:Defaulting to the only supported framework/algorithm version: latest.
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.
# INFO:sagemaker:Creating training-job with name: obstacles-classification-2022-11-30-14-14-14
# 2022-11-30 14:14:14 Starting - Starting the training job...
# 2022-11-30 14:14:38 Starting - Preparing the instances for trainingProfilerReport-1669817654: InProgress
# ......
# 2022-11-30 14:15:38 Downloading - Downloading input data..............................
# 2022-11-30 14:20:45 Training - Training image download completed. Training in progress..2022-11-30 14:20:48.396538: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2022-11-30 14:20:48.406462: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# 2022-11-30 14:20:48.720928: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2022-11-30 14:20:52,171 sagemaker-training-toolkit INFO     Imported framework sagemaker_tensorflow_container.training
# 2022-11-30 14:20:52,178 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2022-11-30 14:20:52,615 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2022-11-30 14:20:52,632 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2022-11-30 14:20:52,649 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2022-11-30 14:20:52,659 sagemaker-training-toolkit INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "eval": "/opt/ml/input/data/eval",
#         "training": "/opt/ml/input/data/training",
#         "validation": "/opt/ml/input/data/validation"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "batch-size": 32,
#         "dataframe_dir": "s3://obstacles-classification/nov22_c_2__1_0",
#         "epochs": 30,
#         "learning-rate": 5e-05,
#         "model_dir": "s3://sagemaker-eu-west-1-947805154784/obstacles_classification/jobs/nov22_c_2__1_0/obstacles-classification-2022-11-30-14-14-14/model",
#         "optimizer": "adam"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "eval": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "validation": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "obstacles-classification-2022-11-30-14-14-14",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-eu-west-1-947805154784/obstacles_classification/jobs/nov22_c_2__1_0/obstacles-classification-2022-11-30-14-14-14/source/sourcedir.tar.gz",
#     "module_name": "train",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "current_instance_type": "ml.c5.xlarge",
#         "current_group_name": "homogeneousCluster",
#         "hosts": [
#             "algo-1"
#         ],
#         "instance_groups": [
#             {
#                 "instance_group_name": "homogeneousCluster",
#                 "instance_type": "ml.c5.xlarge",
#                 "hosts": [
#                     "algo-1"
#                 ]
#             }
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "train.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batch-size":32,"dataframe_dir":"s3://obstacles-classification/nov22_c_2__1_0","epochs":30,"learning-rate":5e-05,"model_dir":"s3://sagemaker-eu-west-1-947805154784/obstacles_classification/jobs/nov22_c_2__1_0/obstacles-classification-2022-11-30-14-14-14/model","optimizer":"adam"}
# SM_USER_ENTRY_POINT=train.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.c5.xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.c5.xlarge"}],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"eval":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["eval","training","validation"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=train
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-eu-west-1-947805154784/obstacles_classification/jobs/nov22_c_2__1_0/obstacles-classification-2022-11-30-14-14-14/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"eval":"/opt/ml/input/data/eval","training":"/opt/ml/input/data/training","validation":"/opt/ml/input/data/validation"},"current_host":"algo-1","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1"],"hyperparameters":{"batch-size":32,"dataframe_dir":"s3://obstacles-classification/nov22_c_2__1_0","epochs":30,"learning-rate":5e-05,"model_dir":"s3://sagemaker-eu-west-1-947805154784/obstacles_classification/jobs/nov22_c_2__1_0/obstacles-classification-2022-11-30-14-14-14/model","optimizer":"adam"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"eval":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"obstacles-classification-2022-11-30-14-14-14","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-eu-west-1-947805154784/obstacles_classification/jobs/nov22_c_2__1_0/obstacles-classification-2022-11-30-14-14-14/source/sourcedir.tar.gz","module_name":"train","network_interface_name":"eth0","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.c5.xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.c5.xlarge"}],"network_interface_name":"eth0"},"user_entry_point":"train.py"}
# SM_USER_ARGS=["--batch-size","32","--dataframe_dir","s3://obstacles-classification/nov22_c_2__1_0","--epochs","30","--learning-rate","5e-05","--model_dir","s3://sagemaker-eu-west-1-947805154784/obstacles_classification/jobs/nov22_c_2__1_0/obstacles-classification-2022-11-30-14-14-14/model","--optimizer","adam"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_EVAL=/opt/ml/input/data/eval
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# SM_CHANNEL_VALIDATION=/opt/ml/input/data/validation
# SM_HP_BATCH-SIZE=32
# SM_HP_DATAFRAME_DIR=s3://obstacles-classification/nov22_c_2__1_0
# SM_HP_EPOCHS=30
# SM_HP_LEARNING-RATE=5e-05
# SM_HP_MODEL_DIR=s3://sagemaker-eu-west-1-947805154784/obstacles_classification/jobs/nov22_c_2__1_0/obstacles-classification-2022-11-30-14-14-14/model
# SM_HP_OPTIMIZER=adam
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/local/lib/python37.zip:/usr/local/lib/python3.7:/usr/local/lib/python3.7/lib-dynload:/usr/local/lib/python3.7/site-packages
# Invoking script with the following command:
# /usr/local/bin/python3.7 train.py --batch-size 32 --dataframe_dir s3://obstacles-classification/nov22_c_2__1_0 --epochs 30 --learning-rate 5e-05 --model_dir s3://sagemaker-eu-west-1-947805154784/obstacles_classification/jobs/nov22_c_2__1_0/obstacles-classification-2022-11-30-14-14-14/model --optimizer adam
# [2022-11-30 14:20:54.836 ip-10-0-208-90.eu-west-1.compute.internal:28 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2022-11-30 14:20:55.071 ip-10-0-208-90.eu-west-1.compute.internal:28 INFO profiler_config_parser.py:102] User has disabled profiler.
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 200, 200, 3) 0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 200, 200, 3) 0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 200, 200, 1) 0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 200, 200, 7)  0           input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 200, 200, 16) 1024        concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 200, 200, 16) 64          conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 100, 100, 16) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 100, 100, 32) 12832       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 100, 100, 32) 128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 50, 50, 32)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 50, 50, 64)   51264       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 50, 50, 64)   256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 25, 25, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 25, 25, 128)  204928      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 25, 25, 128)  512         conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 13, 13, 128)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 13, 13, 256)  819456      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 13, 13, 256)  1024        conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 4, 4, 256)    0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 4096)         0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 4096)         0           flatten[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1)            4097        dropout[0][0]
# ==================================================================================================
# Total params: 1,095,585
# Trainable params: 1,094,593
# Non-trainable params: 992
# __________________________________________________________________________________________________
# ***** steps_per_epoch: 613 ********
# ***** validation_steps: 154 ********
# Found 19588 validated image filenames belonging to 2 classes.
# Epoch 1/30
# Found 4896 validated image filenames belonging to 2 classes.
# lr: 0.00005000
# 613/613 - 557s - loss: 116.3416 - auc: 0.8220 - recall: 0.7706 - specifity: 0.4727 - val_loss: 73.3140 - val_auc: 0.9506 - val_recall: 0.6938 - val_specifity: 0.8579
# Epoch 2/30
# lr: 0.00005000
# 613/613 - 557s - loss: 49.6026 - auc: 0.9530 - recall: 0.8971 - specifity: 0.8596 - val_loss: 36.0226 - val_auc: 0.9799 - val_recall: 0.9475 - val_specifity: 0.9646
# Epoch 3/30
# lr: 0.00005000
# 613/613 - 558s - loss: 31.2724 - auc: 0.9714 - recall: 0.9240 - specifity: 0.9318 - val_loss: 27.6025 - val_auc: 0.9871 - val_recall: 0.9557 - val_specifity: 0.9777
# Epoch 4/30
# lr: 0.00005000
# 613/613 - 558s - loss: 25.2183 - auc: 0.9812 - recall: 0.9373 - specifity: 0.9625 - val_loss: 23.0824 - val_auc: 0.9893 - val_recall: 0.9859 - val_specifity: 0.9835
# Epoch 5/30
# lr: 0.00005000
# 613/613 - 557s - loss: 21.6976 - auc: 0.9844 - recall: 0.9453 - specifity: 0.9729 - val_loss: 20.4115 - val_auc: 0.9915 - val_recall: 0.9580 - val_specifity: 0.9890
# Epoch 6/30
# lr: 0.00005000
# 613/613 - 555s - loss: 19.0926 - auc: 0.9878 - recall: 0.9504 - specifity: 0.9815 - val_loss: 18.0041 - val_auc: 0.9895 - val_recall: 0.9745 - val_specifity: 0.9840
# Epoch 7/30
# lr: 0.00005000
# 613/613 - 551s - loss: 17.1924 - auc: 0.9881 - recall: 0.9528 - specifity: 0.9809 - val_loss: 16.6578 - val_auc: 0.9885 - val_recall: 0.8178 - val_specifity: 0.9893
# Epoch 8/30
# lr: 0.00005000
# 613/613 - 553s - loss: 15.5593 - auc: 0.9893 - recall: 0.9543 - specifity: 0.9858 - val_loss: 15.2664 - val_auc: 0.9877 - val_recall: 0.7747 - val_specifity: 0.9870
# Epoch 9/30
# lr: 0.00005000
# 613/613 - 560s - loss: 14.2053 - auc: 0.9903 - recall: 0.9589 - specifity: 0.9875 - val_loss: 13.7367 - val_auc: 0.9913 - val_recall: 0.9295 - val_specifity: 0.9907
# Epoch 10/30
# lr: 0.00001250
# 613/613 - 556s - loss: 6.8378 - auc: 0.9956 - recall: 0.9706 - specifity: 0.9962 - val_loss: 6.7803 - val_auc: 0.9969 - val_recall: 0.9561 - val_specifity: 0.9979
# Epoch 29/30
# lr: 0.00001250
# 613/613 - 559s - loss: 6.6893 - auc: 0.9956 - recall: 0.9711 - specifity: 0.9962 - val_loss: 6.5755 - val_auc: 0.9971 - val_recall: 0.9852 - val_specifity: 0.9975
# Epoch 30/30
# lr: 0.00001250
# 613/613 - 561s - loss: 6.5258 - auc: 0.9955 - recall: 0.9705 - specifity: 0.9952 - val_loss: 6.4268 - val_auc: 0.9967 - val_recall: 0.9845 - val_specifity: 0.9962
# Found 2553 images belonging to 2 classes.
# #015  1/300 [..............................] - ETA: 0s - loss: 6.2882 - auc: 1.0000 - recall: 1.0000 - specifity: 1.0000#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015  2/300 [..............................] - ETA: 50s - loss: 6.3163 - auc: 0.9980 - recall: 1.0000 - specifity: 1.0000#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015  3/300 [..............................] - ETA: 1:05 - loss: 6.3052 - auc: 0.9987 - recall: 1.0000 - specifity: 1.0000#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015  4/300 [..............................] - ETA: 1:15 - loss: 6.3077 - auc: 0.9990 - recall: 1.0000 - specifity: 1.0000#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015  5/300 [..............................] - ETA: 1:18 - loss: 6.3060 - auc: 0.9994 - recall: 1.0000 - specifity: 1.0000#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015  6/300 [..............................] - ETA: 1:23 - loss: 6.3225 - auc: 0.9964 - recall: 0.9780 - specifity: 1.0000#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015  7/300 [..............................] - ETA: 1:25 - loss: 6.3157 - auc: 0.9971 - recall: 0.9820 - specifity: 1.0000#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010# ...
# ...] - ETA: 1:15 - loss: 6.3177 - auc: 0.9973 - recall: 0.9772 - specifity: 0.9973#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 71/300 [======>.......................] - ETA: 1:15 - loss: 6.3175 - auc: 0.9973 - recall: 0.9775 - specifity: 0.9973#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 72/300 [======>.......................] - ETA: 1:15 - loss: 6.3182 - auc: 0.9972 - recall: 0.9770 - specifity: 0.9973#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 73/300 [======>.......................] - ETA: 1:14 - loss: 6.3177 - auc: 0.9973 - recall: 0.9774 - specifity: 0.9974#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 74/300 [======>.......................] - ETA: 1:14 - loss: 6.3170 - auc: 0.9973 - recall: 0.9777 - specifity: 0.9974#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 75/300 [======>.......................] - ETA: 1:14 - loss: 6.3170 - auc: 0.9974 - recall: 0.9772 - specifity: 0.9974#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 76/300 [======>.......................] - ETA: 1:13 - loss: 6.3176 - auc: 0.9972 - recall: 0.9766 - specifity: 0.9975#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0 ...
# ity: 0.9982#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015140/300 [=============>................] - ETA: 53s - loss: 6.3167 - auc: 0.9972 - recall: 0.9777 - specifity: 0.9982#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015141/300 [=============>................] - ETA: 52s - loss: 6.3165 - auc: 0.9972 - recall: 0.9779 - specifity: 0.9982#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015142/300 [=============>................] - ETA: 52s - loss: 6.3171 - auc: 0.9971 - recall: 0.9781 - specifity: 0.9977#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015143/300 [=============>................] - ETA: 52s - loss: 6.3169 - auc: 0.9972 - recall: 0.9782 - specifity: 0.9978#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015144/300 [=============>................] - ETA: 51s - loss: 6.3174 - auc: 0.9971 - recall: 0.9784 - specifity: 0.9978#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#