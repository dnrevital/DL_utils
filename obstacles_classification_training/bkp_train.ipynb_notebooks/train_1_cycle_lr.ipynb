# %%
import time

train_dataset_name = '7sw_1_5__1'
eval_dataset_name = '7sw_1_5__1'
dataset_hyphened_name = train_dataset_name.replace('_', '-') + '-' + f'{time.strftime("%Y-%m-%d-%H-%M-%S", time.gmtime())}'
layers = 5

# %% [markdown]
# ### Client & SM sessions

# %%
import sagemaker, boto3

sess = boto3.Session()
sm   = sess.client('sagemaker')
role = sagemaker.get_execution_role()
sagemaker_session = sagemaker.Session(boto_session=sess)

# %% [markdown]
# ### Create experiment

# %%
from smexperiments.experiment import Experiment
from smexperiments.trial import Trial
from smexperiments.trial_component import TrialComponent

training_experiment = Experiment.create(experiment_name = f'{dataset_hyphened_name}', 
                                        description     = f'{dataset_hyphened_name}', 
                                        sagemaker_boto_client=sm)

# %% [markdown]
# ### Create trial

# %%
training_trial = Trial.create(trial_name = f'{dataset_hyphened_name}', 
                              experiment_name = training_experiment.experiment_name,
                              sagemaker_boto_client = sm,)
training_trial_comp_name = f'{dataset_hyphened_name}'
experiment_config = {"ExperimentName": training_experiment.experiment_name, 
                       "TrialName": training_trial.trial_name,
                       "TrialComponentDisplayName": training_trial_comp_name}

# %% [markdown]
# ### Run training job & visualize results

# %%
from sagemaker.tensorflow import TensorFlow

dataframe_dir = f's3://obstacles-classification/{train_dataset_name}'

hyperparams={'epochs'       : 100,
             'learning-rate': 0.00015,
             'batch-size'   : 32,
             'optimizer'    : 'adam',
             'dataframe_dir': dataframe_dir
            }

bucket_name = sagemaker_session.default_bucket()
output_path = f's3://{bucket_name}/obstacles_classification/jobs/{train_dataset_name}'

metric_definitions = [
    {'Name': 'auc', 'Regex': 'auc: ([0-9\\.]+)'},
    {'Name': 'recall', 'Regex': 'recall: ([0-9\\.]+)'},
    {'Name': 'specifity', 'Regex': 'specifity: ([0-9\\.]+)'},
    {'Name': 'accuracy', 'Regex': 'accuracy: ([0-9\\.]+)'},
    {'Name': 'loss', 'Regex': 'loss: ([0-9\\.]+)'},
    {'Name': 'validation auc', 'Regex': 'val_auc: ([0-9\\.]+)'},
    {'Name': 'validation recall', 'Regex': 'val_recall: ([0-9\\.]+)'},
    {'Name': 'validation specifity', 'Regex': 'val_specifity: ([0-9\\.]+)'},
    {'Name': 'validation accuracy', 'Regex': 'val_categorical_accuracy: ([0-9\\.]+)'},
    {'Name': 'validation loss', 'Regex': 'val_loss: ([0-9\\.]+)'},
    {'Name': 'test auc', 'Regex': 'test_auc: ([0-9\\.]+)'},
    {'Name': 'test recall', 'Regex': 'test_recall: ([0-9\\.]+)'},
    {'Name': 'test specifity', 'Regex': 'test_specifity: ([0-9\\.]+)'},
    {'Name': 'test accuracy', 'Regex': 'test_accuracy: ([0-9\\.]+)'},
    {'Name': 'test loss', 'Regex': 'test_loss: ([0-9\\.]+)'},
    {'Name': 'epoch', 'Regex': 'Epoch ([0-9]+)'},
]

tf_estimator = TensorFlow(entry_point          = '7_channels_weights_1_cycle_lr.py', 
                          output_path          = f'{output_path}/',
                          code_location        = output_path,
                          role                 = role,
                          train_instance_count = 1, 
                          train_instance_type  = 'ml.c5.xlarge',
                          framework_version    = '2.3', 
                          py_version           = 'py37',
                          script_mode          = True,
                          metric_definitions   = metric_definitions,
                          debugger_hook_config = False,
                          sagemaker_session    = sagemaker_session,
                          hyperparameters      = hyperparams)

job_name=f'obstacles-classification-{time.strftime("%Y-%m-%d-%H-%M-%S", time.gmtime())}'
training_dataset = f's3://obstacles-classification/{train_dataset_name}/train'
eval_dataset = f's3://obstacles-classification/{train_dataset_name}/eval'
tf_estimator.fit({'training'  : training_dataset,
                  'validation': training_dataset,
                  'eval'      : eval_dataset},   
                  job_name = job_name,
                  experiment_config=experiment_config)
# Out:
# WARNING:sagemaker.deprecations:train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# WARNING:sagemaker.deprecations:train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# WARNING:sagemaker.deprecations:train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# INFO:sagemaker.image_uris:Defaulting to the only supported framework/algorithm version: latest.
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.
# INFO:sagemaker:Creating training-job with name: obstacles-classification-2022-01-13-08-13-26
# 2022-01-13 08:13:26 Starting - Starting the training job...
# 2022-01-13 08:13:49 Starting - Launching requested ML instancesProfilerReport-1642061606: InProgress
# ......
# 2022-01-13 08:14:50 Starting - Preparing the instances for training......
# 2022-01-13 08:15:50 Downloading - Downloading input data............
# 2022-01-13 08:17:50 Training - Downloading the training image..2022-01-13 08:18:01.996343: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2022-01-13 08:18:02.006072: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# 2022-01-13 08:18:02.348582: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2022-01-13 08:18:06,359 sagemaker-training-toolkit INFO     Imported framework sagemaker_tensorflow_container.training
# 2022-01-13 08:18:06,367 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2022-01-13 08:18:06,837 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2022-01-13 08:18:06,853 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2022-01-13 08:18:06,869 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2022-01-13 08:18:06,879 sagemaker-training-toolkit INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "eval": "/opt/ml/input/data/eval",
#         "training": "/opt/ml/input/data/training",
#         "validation": "/opt/ml/input/data/validation"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "batch-size": 32,
#         "learning-rate": 0.00015,
#         "dataframe_dir": "s3://obstacles-classification/7sw_1_5__1",
#         "optimizer": "adam",
#         "model_dir": "s3://sagemaker-eu-west-1-947805154784/obstacles_classification/jobs/7sw_1_5__1/obstacles-classification-2022-01-13-08-13-26/model",
#         "epochs": 100
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "eval": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "validation": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "obstacles-classification-2022-01-13-08-13-26",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-eu-west-1-947805154784/obstacles_classification/jobs/7sw_1_5__1/obstacles-classification-2022-01-13-08-13-26/source/sourcedir.tar.gz",
#     "module_name": "7_channels_weights_1_cycle_lr",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "7_channels_weights_1_cycle_lr.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batch-size":32,"dataframe_dir":"s3://obstacles-classification/7sw_1_5__1","epochs":100,"learning-rate":0.00015,"model_dir":"s3://sagemaker-eu-west-1-947805154784/obstacles_classification/jobs/7sw_1_5__1/obstacles-classification-2022-01-13-08-13-26/model","optimizer":"adam"}
# SM_USER_ENTRY_POINT=7_channels_weights_1_cycle_lr.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"eval":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["eval","training","validation"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=7_channels_weights_1_cycle_lr
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-eu-west-1-947805154784/obstacles_classification/jobs/7sw_1_5__1/obstacles-classification-2022-01-13-08-13-26/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"eval":"/opt/ml/input/data/eval","training":"/opt/ml/input/data/training","validation":"/opt/ml/input/data/validation"},"current_host":"algo-1","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1"],"hyperparameters":{"batch-size":32,"dataframe_dir":"s3://obstacles-classification/7sw_1_5__1","epochs":100,"learning-rate":0.00015,"model_dir":"s3://sagemaker-eu-west-1-947805154784/obstacles_classification/jobs/7sw_1_5__1/obstacles-classification-2022-01-13-08-13-26/model","optimizer":"adam"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"eval":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"obstacles-classification-2022-01-13-08-13-26","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-eu-west-1-947805154784/obstacles_classification/jobs/7sw_1_5__1/obstacles-classification-2022-01-13-08-13-26/source/sourcedir.tar.gz","module_name":"7_channels_weights_1_cycle_lr","network_interface_name":"eth0","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"7_channels_weights_1_cycle_lr.py"}
# SM_USER_ARGS=["--batch-size","32","--dataframe_dir","s3://obstacles-classification/7sw_1_5__1","--epochs","100","--learning-rate","0.00015","--model_dir","s3://sagemaker-eu-west-1-947805154784/obstacles_classification/jobs/7sw_1_5__1/obstacles-classification-2022-01-13-08-13-26/model","--optimizer","adam"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_EVAL=/opt/ml/input/data/eval
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# SM_CHANNEL_VALIDATION=/opt/ml/input/data/validation
# SM_HP_BATCH-SIZE=32
# SM_HP_LEARNING-RATE=0.00015
# SM_HP_DATAFRAME_DIR=s3://obstacles-classification/7sw_1_5__1
# SM_HP_OPTIMIZER=adam
# SM_HP_MODEL_DIR=s3://sagemaker-eu-west-1-947805154784/obstacles_classification/jobs/7sw_1_5__1/obstacles-classification-2022-01-13-08-13-26/model
# SM_HP_EPOCHS=100
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/local/lib/python37.zip:/usr/local/lib/python3.7:/usr/local/lib/python3.7/lib-dynload:/usr/local/lib/python3.7/site-packages
# Invoking script with the following command:
# /usr/local/bin/python3.7 7_channels_weights_1_cycle_lr.py --batch-size 32 --dataframe_dir s3://obstacles-classification/7sw_1_5__1 --epochs 100 --learning-rate 0.00015 --model_dir s3://sagemaker-eu-west-1-947805154784/obstacles_classification/jobs/7sw_1_5__1/obstacles-classification-2022-01-13-08-13-26/model --optimizer adam
# [2022-01-13 08:18:09.348 ip-10-0-129-113.eu-west-1.compute.internal:27 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2022-01-13 08:18:09.556 ip-10-0-129-113.eu-west-1.compute.internal:27 INFO profiler_config_parser.py:102] User has disabled profiler.
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 200, 200, 3) 0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 200, 200, 3) 0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 200, 200, 1) 0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 200, 200, 7)  0           input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 200, 200, 16) 1024        concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 200, 200, 16) 64          conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 100, 100, 16) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 100, 100, 32) 12832       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 100, 100, 32) 128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 50, 50, 32)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 50, 50, 64)   51264       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 50, 50, 64)   256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 25, 25, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 25, 25, 128)  204928      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 25, 25, 128)  512         conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 13, 13, 128)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 13, 13, 256)  819456      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 13, 13, 256)  1024        conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 4, 4, 256)    0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 4096)         0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 4096)         0           flatten[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1)            4097        dropout[0][0]
# ==================================================================================================
# Total params: 1,095,585
# Trainable params: 1,094,593
# Non-trainable params: 992
# __________________________________________________________________________________________________
# Found 10468 validated image filenames belonging to 2 classes.
# Epoch 1/100
#
# 2022-01-13 08:18:10 Training - Training image download completed. Training in progress.Found 2616 validated image filenames belonging to 2 classes.
# lr: 0.00017834
# 328/328 - 298s - loss: 68.0707 - auc: 0.9379 - recall: 0.9045 - specifity: 0.8217 - val_loss: 21.9411 - val_auc: 0.8326 - val_recall: 0.0000e+00 - val_specifity: 0.0598
# Epoch 2/100
# lr: 0.00020676
# 328/328 - 298s - loss: 11.5427 - auc: 0.9786 - recall: 0.9425 - specifity: 0.9606 - val_loss: 9.3307 - val_auc: 0.9828 - val_recall: 0.1620 - val_specifity: 0.9711
# Epoch 3/100
# lr: 0.00023518
# 328/328 - 302s - loss: 7.1070 - auc: 0.9789 - recall: 0.9469 - specifity: 0.9556 - val_loss: 7.1295 - val_auc: 0.9729 - val_recall: 0.9972 - val_specifity: 0.9594
# Epoch 4/100
# lr: 0.00026360
# 328/328 - 299s - loss: 4.9094 - auc: 0.9839 - recall: 0.9530 - specifity: 0.9703 - val_loss: 4.7028 - val_auc: 0.9804 - val_recall: 0.6252 - val_specifity: 0.9859
# Epoch 5/100
# lr: 0.00029203
# 328/328 - 299s - loss: 3.5126 - auc: 0.9840 - recall: 0.9528 - specifity: 0.9752 - val_loss: 3.3347 - val_auc: 0.9907 - val_recall: 0.6237 - val_specifity: 0.9867
# Epoch 6/100
# lr: 0.00032045
# 328/328 - 300s - loss: 2.9484 - auc: 0.9845 - recall: 0.9531 - specifity: 0.9761 - val_loss: 3.6034 - val_auc: 0.9699 - val_recall: 0.9509 - val_specifity: 0.9673
# Epoch 7/100
# lr: 0.00034887
# 328/328 - 301s - loss: 4.5916 - auc: 0.9701 - recall: 0.9425 - specifity: 0.9292 - val_loss: 4.8717 - val_auc: 0.9348 - val_recall: 0.4308 - val_specifity: 0.7652
# Epoch 8/100
# lr: 0.00037730
# 328/328 - 299s - loss: 2.8701 - auc: 0.9856 - recall: 0.9572 - specifity: 0.9755 - val_loss: 2.4280 - val_auc: 0.9817 - val_recall: 0.8277 - val_specifity: 0.9520
# Epoch 9/100
# lr: 0.00040572
# 328/328 - 302s - loss: 1.8496 - auc: 0.9905 - recall: 0.9693 - specifity: 0.9871 - val_loss: 1.7324 - val_auc: 0.9961 - val_recall: 0.8575 - val_specifity: 0.9958
# Epoch 10/100
# lr: 0.00043414
# 328/328 - 303s - loss: 1.5218 - auc: 0.9920 - recall: 0.9700 - specifity: 0.9888 - val_loss: 2.0066 - val_auc: 0.9932 - val_recall: 0.4958 - val_specifity: 0.9941
# Epoch 11/100
# lr: 0.00046256
# 328/328 - 304s - loss: 1.4292 - auc: 0.9900 - recall: 0.9631 - specifity: 0.9823 - val_loss: 1.5885 - val_auc: 0.9816 - val_recall: 0.9821 - val_specifity: 0.9704
# Epoch 12/100
# lr: 0.00049099
# 328/328 - 303s - loss: 1.8346 - auc: 0.9840 - recall: 0.9509 - specifity: 0.9686 - val_loss: 2.2143 - val_auc: 0.9916 - val_recall: 0.7859 - val_specifity: 0.9891
# Epoch 13/100
# lr: 0.00051941
# 328/328 - 304s - loss: 1.5192 - auc: 0.9861 - recall: 0.9559 - specifity: 0.9780 - val_loss: 2.3148 - val_auc: 0.9891 - val_recall: 0.3442 - val_specifity: 0.9917
# Epoch 14/100
# lr: 0.00054783
# 328/328 - 304s - loss: 2.1422 - auc: 0.9778 - recall: 0.9375 - specifity: 0.9507 - val_loss: 1.5989 - val_auc: 0.9851 - val_recall: 0.8848 - val_specifity: 0.9651
# Epoch 15/100
# lr: 0.00057626
# 328/328 - 308s - loss: 1.8112 - auc: 0.9828 - recall: 0.9452 - specifity: 0.9696 - val_loss: 3.2452 - val_auc: 0.9736 - val_recall: 0.0282 - val_specifity: 0.9359
# Epoch 16/100
# lr: 0.00060468
# 328/328 - 304s - loss: 1.1724 - auc: 0.9868 - recall: 0.9526 - specifity: 0.9793 - val_loss: 1.8628 - val_auc: 0.9146 - val_recall: 0.8926 - val_specifity: 0.7190
# Epoch 17/100
# lr: 0.00063310
# 328/328 - 304s - loss: 2.8262 - auc: 0.9701 - recall: 0.9272 - specifity: 0.9395 - val_loss: 3.9300 - val_auc: 0.9137 - val_recall: 0.5075 - val_specifity: 0.7412
# Epoch 18/100
# lr: 0.00066153
# 328/328 - 304s - loss: 1.7299 - auc: 0.9834 - recall: 0.9435 - specifity: 0.9716 - val_loss: 1.5537 - val_auc: 0.9891 - val_recall: 0.7286 - val_specifity: 0.9874
# Epoch 19/100
# lr: 0.00068995
# 328/328 - 303s - loss: 1.1573 - auc: 0.9854 - recall: 0.9463 - specifity: 0.9765 - val_loss: 1.4675 - val_auc: 0.9680 - val_recall: 0.7565 - val_specifity: 0.9446
# Epoch 20/100
# lr: 0.00071837
# 328/328 - 305s - loss: 5.1580 - auc: 0.9499 - recall: 0.8994 - specifity: 0.8652 - val_loss: 5.6722 - val_auc: 0.9434 - val_recall: 0.1042 - val_specifity: 0.8126
# Epoch 21/100
# lr: 0.00074679
# 328/328 - 304s - loss: 3.0922 - auc: 0.9774 - recall: 0.9284 - specifity: 0.9619 - val_loss: 3.8772 - val_auc: 0.8940 - val_recall: 0.1205 - val_specifity: 0.6620
# Epoch 22/100
# lr: 0.00077522
# 328/328 - 304s - loss: 2.1118 - auc: 0.9846 - recall: 0.9430 - specifity: 0.9714 - val_loss: 1.2599 - val_auc: 0.9826 - val_recall: 0.9091 - val_specifity: 0.9661
# Epoch 23/100
# lr: 0.00080364
# 328/328 - 301s - loss: 1.9554 - auc: 0.9792 - recall: 0.9401 - specifity: 0.9556 - val_loss: 12.4571 - val_auc: 0.5067 - val_recall: 0.3815 - val_specifity: 0.0000e+00
# Epoch 24/100
# lr: 0.00083206
# 328/328 - 308s - loss: 3.5403 - auc: 0.9664 - recall: 0.9181 - specifity: 0.9330 - val_loss: 4.0814 - val_auc: 0.9504 - val_recall: 0.5128 - val_specifity: 0.8823
# Epoch 25/100
# lr: 0.00086049
# 328/328 - 304s - loss: 2.4883 - auc: 0.9808 - recall: 0.9341 - specifity: 0.9649 - val_loss: 2.8080 - val_auc: 0.9842 - val_recall: 0.1402 - val_specifity: 0.9704
# Epoch 26/100
# lr: 0.00088891
# 328/328 - 302s - loss: 2.9153 - auc: 0.9734 - recall: 0.9306 - specifity: 0.9350 - val_loss: 1.5295 - val_auc: 0.9890 - val_recall: 0.8827 - val_specifity: 0.9872
# Epoch 27/100
# lr: 0.00091733
# 328/328 - 301s - loss: 1.4546 - auc: 0.9856 - recall: 0.9430 - specifity: 0.9737 - val_loss: 1.5441 - val_auc: 0.9805 - val_recall: 0.8571 - val_specifity: 0.9770
# Epoch 28/100
# lr: 0.00100260
# 328/328 - 301s - loss: 3.1097 - auc: 0.9700 - recall: 0.9160 - specifity: 0.9283 - val_loss: 2.5711 - val_auc: 0.9735 - val_recall: 0.6396 - val_specifity: 0.9425
# Epoch 31/100
# lr: 0.00103102
# 328/328 - 303s - loss: 2.2453 - auc: 0.9765 - recall: 0.9282 - specifity: 0.9522 - val_loss: 12.1277 - val_auc: 0.6773 - val_recall: 0.3772 - val_specifity: 0.0000e+00
# Epoch 32/100
# lr: 0.00105945
# 328/328 - 306s - loss: 7.0534 - auc: 0.9130 - recall: 0.8656 - specifity: 0.7287 - val_loss: 7.3048 - val_auc: 0.6594 - val_recall: 0.7755 - val_specifity: 0.4650
# Epoch 33/100
# lr: 0.00108787
# 328/328 - 304s - loss: 4.0640 - auc: 0.9561 - recall: 0.9001 - specifity: 0.8863 - val_loss: 3.1342 - val_auc: 0.9791 - val_recall: 0.8208 - val_specifity: 0.9661
# Epoch 34/100
# lr: 0.00111629
# 328/328 - 305s - loss: 3.3674 - auc: 0.9610 - recall: 0.9076 - specifity: 0.9104 - val_loss: 4.1795 - val_auc: 0.9402 - val_recall: 7.0522e-04 - val_specifity: 0.7980
# Epoch 35/100
# lr: 0.00114471
# 328/328 - 302s - loss: 4.3397 - auc: 0.9360 - recall: 0.8826 - specifity: 0.7963 - val_loss: 4.0086 - val_auc: 0.9482 - val_recall: 0.0508 - val_specifity: 0.8465
# Epoch 36/100
# lr: 0.00117314
# 328/328 - 305s - loss: 2.2652 - auc: 0.9761 - recall: 0.9315 - specifity: 0.9552 - val_loss: 4.6756 - val_auc: 0.7762 - val_recall: 0.0028 - val_specifity: 0.1613
# Epoch 37/100
# lr: 0.00148579
# 328/328 - 339s - loss: 2.7552 - auc: 0.9756 - recall: 0.9272 - specifity: 0.9496 - val_loss: 3.4104 - val_auc: 0.7986 - val_recall: 0.8130 - val_specifity: 0.4344
# Epoch 48/100
# lr: 0.00148588
# 328/328 - 306s - loss: 2.8744 - auc: 0.9768 - recall: 0.9289 - specifity: 0.9535 - val_loss: 2.8835 - val_auc: 0.9839 - val_recall: 0.7741 - val_specifity: 0.9859
# Epoch 49/100
# lr: 0.00145745
# 328/328 - 306s - loss: 3.0981 - auc: 0.9734 - recall: 0.9229 - specifity: 0.9444 - val_loss: 78.6539 - val_auc: 0.5353 - val_recall: 1.0000 - val_specifity: 0.0706
# Epoch 50/100
# lr: 0.00142903
# 328/328 - 307s - loss: 2.7627 - auc: 0.9782 - recall: 0.9277 - specifity: 0.9593 - val_loss: 4.3794 - val_auc: 0.5151 - val_recall: 0.9350 - val_specifity: 0.1923
# Epoch 51/100
# lr: 0.00140061
# 328/328 - 307s - loss: 2.4382 - auc: 0.9824 - recall: 0.9330 - specifity: 0.9711 - val_loss: 2.2808 - val_auc: 0.9901 - val_recall: 0.7568 - val_specifity: 0.9828
# Epoch 52/100
# lr: 0.00137218
# 328/328 - 306s - loss: 2.0662 - auc: 0.9856 - recall: 0.9423 - specifity: 0.9789 - val_loss: 2.1980 - val_auc: 0.9808 - val_recall: 0.8392 - val_specifity: 0.9811
# Epoch 53/100
# lr: 0.00134376
# 328/328 - 308s - loss: 2.6250 - auc: 0.9775 - recall: 0.9241 - specifity: 0.9475 - val_loss: 2.3268 - val_auc: 0.9810 - val_recall: 0.8909 - val_specifity: 0.9384
# Epoch 54/100
# lr: 0.00131534
# 328/328 - 307s - loss: 2.4467 - auc: 0.9815 - recall: 0.9394 - specifity: 0.9716 - val_loss: 5.3693 - val_auc: 0.8568 - val_recall: 0.0043 - val_specifity: 0.0320
# Epoch 55/100
# lr: 0.00128692
# 328/328 - 306s - loss: 2.3471 - auc: 0.9800 - recall: 0.9311 - specifity: 0.9653 - val_loss: 2.1711 - val_auc: 0.9885 - val_recall: 0.8634 - val_specifity: 0.9883
# Epoch 56/100
# lr: 0.00125849
# 328/328 - 307s - loss: 2.2223 - auc: 0.9833 - recall: 0.9341 - specifity: 0.9714 - val_loss: 3.2745 - val_auc: 0.9844 - val_recall: 0.3755 - val_specifity: 0.9792
# Epoch 57/100
# lr: 0.00123007
# 328/328 - 304s - loss: 2.6428 - auc: 0.9816 - recall: 0.9392 - specifity: 0.9718 - val_loss: 2.4857 - val_auc: 0.9637 - val_recall: 0.6799 - val_specifity: 0.9347
# Epoch 58/100
# lr: 0.00120165
# 328/328 - 362s - loss: 1.9623 - auc: 0.9878 - recall: 0.9439 - specifity: 0.9802 - val_loss: 4.1661 - val_auc: 0.8604 - val_recall: 0.9958 - val_specifity: 0.7342
# Epoch 59/100
# lr: 0.00117322
# 328/328 - 305s - loss: 2.0550 - auc: 0.9869 - recall: 0.9425 - specifity: 0.9804 - val_loss: 2.0795 - val_auc: 0.9929 - val_recall: 0.7209 - val_specifity: 0.9949
# Epoch 60/100
# lr: 0.00114480
# 328/328 - 305s - loss: 1.9789 - auc: 0.9855 - recall: 0.9447 - specifity: 0.9774 - val_loss: 1.8744 - val_auc: 0.9899 - val_recall: 0.9242 - val_specifity: 0.9827
# Epoch 61/100
# lr: 0.00111638
# 328/328 - 304s - loss: 1.7120 - auc: 0.9897 - recall: 0.9542 - specifity: 0.9897 - val_loss: 1.6120 - val_auc: 0.9916 - val_recall: 0.9722 - val_specifity: 0.9890
# Epoch 62/100
# lr: 0.00108795
# 328/328 - 299s - loss: 1.8260 - auc: 0.9858 - recall: 0.9490 - specifity: 0.9776 - val_loss: 2.1358 - val_auc: 0.9868 - val_recall: 0.9914 - val_specifity: 0.9877
# Epoch 63/100
# lr: 0.00105953
# 328/328 - 299s - loss: 1.7744 - auc: 0.9895 - recall: 0.9464 - specifity: 0.9839 - val_loss: 3.0415 - val_auc: 0.8278 - val_recall: 0.9163 - val_specifity: 0.6098
# Epoch 64/100
# lr: 0.00103111
# 328/328 - 305s - loss: 2.1962 - auc: 0.9808 - recall: 0.9363 - specifity: 0.9580 - val_loss: 1.9405 - val_auc: 0.9909 - val_recall: 0.8366 - val_specifity: 0.9856
# Epoch 65/100
# lr: 0.00100269
# 328/328 - 302s - loss: 1.6865 - auc: 0.9854 - recall: 0.9452 - specifity: 0.9791 - val_loss: 10.9606 - val_auc: 0.6221 - val_recall: 0.0886 - val_specifity: 0.0000e+00
# Epoch 66/100
# lr: 0.00097426
# 328/328 - 304s - loss: 1.9060 - auc: 0.9854 - recall: 0.9433 - specifity: 0.9817 - val_loss: 1.7216 - val_auc: 0.9914 - val_recall: 0.8577 - val_specifity: 0.9892
# Epoch 67/100
# lr: 0.00094584
# 328/328 - 304s - loss: 1.5332 - auc: 0.9898 - recall: 0.9519 - specifity: 0.9821 - val_loss: 1.5909 - val_auc: 0.9902 - val_recall: 0.8666 - val_specifity: 0.9832
# Epoch 68/100
# lr: 0.00091742
# 328/328 - 304s - loss: 1.8370 - auc: 0.9828 - recall: 0.9372 - specifity: 0.9671 - val_loss: 1.8054 - val_auc: 0.9816 - val_recall: 0.9950 - val_specifity: 0.9737
# Epoch 69/100
# lr: 0.00088899
# 328/328 - 304s - loss: 1.4260 - auc: 0.9917 - recall: 0.9593 - specifity: 0.9886 - val_loss: 1.7605 - val_auc: 0.9852 - val_recall: 0.9943 - val_specifity: 0.9851
# Epoch 70/100
# lr: 0.00086057
# 328/328 - 305s - loss: 1.3816 - auc: 0.9910 - recall: 0.9559 - specifity: 0.9899 - val_loss: 1.5994 - val_auc: 0.9948 - val_recall: 0.8292 - val_specifity: 0.9992
# Epoch 71/100
# lr: 0.00083215
# 328/328 - 307s - loss: 1.9783 - auc: 0.9862 - recall: 0.9502 - specifity: 0.9806 - val_loss: 3.0701 - val_auc: 0.9310 - val_recall: 0.9732 - val_specifity: 0.8998
# Epoch 72/100
# lr: 0.00080373
# 328/328 - 308s - loss: 1.5488 - auc: 0.9920 - recall: 0.9584 - specifity: 0.9866 - val_loss: 1.4579 - val_auc: 0.9950 - val_recall: 0.8655 - val_specifity: 0.9958
# Epoch 73/100
# lr: 0.00077530
# 328/328 - 309s - loss: 1.3655 - auc: 0.9903 - recall: 0.9584 - specifity: 0.9843 - val_loss: 1.5296 - val_auc: 0.9936 - val_recall: 0.7817 - val_specifity: 0.9967
# Epoch 74/100
# lr: 0.00074688
# 328/328 - 307s - loss: 1.2010 - auc: 0.9932 - recall: 0.9651 - specifity: 0.9927 - val_loss: 1.3703 - val_auc: 0.9953 - val_recall: 0.8478 - val_specifity: 0.9967
# Epoch 75/100
# lr: 0.00071846
# 328/328 - 306s - loss: 1.1970 - auc: 0.9917 - recall: 0.9595 - specifity: 0.9871 - val_loss: 1.2335 - val_auc: 0.9934 - val_recall: 0.8461 - val_specifity: 0.9918
# Epoch 76/100
# lr: 0.00069003
# 328/328 - 304s - loss: 1.0725 - auc: 0.9943 - recall: 0.9703 - specifity: 0.9948 - val_loss: 1.0917 - val_auc: 0.9909 - val_recall: 0.8950 - val_specifity: 0.9773
# Epoch 77/100
# lr: 0.00066161
# 328/328 - 304s - loss: 1.0375 - auc: 0.9929 - recall: 0.9658 - specifity: 0.9903 - val_loss: 0.9783 - val_auc: 0.9945 - val_recall: 0.9778 - val_specifity: 0.9942
# Epoch 78/100
# lr: 0.00063319
# 328/328 - 305s - loss: 0.9855 - auc: 0.9930 - recall: 0.9675 - specifity: 0.9916 - val_loss: 0.9806 - val_auc: 0.9955 - val_recall: 0.9262 - val_specifity: 0.9958
# Epoch 79/100
# lr: 0.00060477
# 328/328 - 307s - loss: 0.9645 - auc: 0.9914 - recall: 0.9588 - specifity: 0.9877 - val_loss: 0.9587 - val_auc: 0.9949 - val_recall: 0.9477 - val_specifity: 0.9908
# Epoch 80/100
