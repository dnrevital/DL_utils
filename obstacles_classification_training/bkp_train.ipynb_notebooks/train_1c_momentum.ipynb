# %%
import time

train_dataset_name = '7sw_1_5__1'
eval_dataset_name = '7sw_1_5__1'
dataset_hyphened_name = train_dataset_name.replace('_', '-') + '-' + f'{time.strftime("%Y-%m-%d-%H-%M-%S", time.gmtime())}'
layers = 5

# %% [markdown]
# ### Client & SM sessions

# %%
import sagemaker, boto3

sess = boto3.Session()
sm   = sess.client('sagemaker')
role = sagemaker.get_execution_role()
sagemaker_session = sagemaker.Session(boto_session=sess)

# %% [markdown]
# ### Create experiment

# %%
from smexperiments.experiment import Experiment
from smexperiments.trial import Trial
from smexperiments.trial_component import TrialComponent

training_experiment = Experiment.create(experiment_name = f'{dataset_hyphened_name}', 
                                        description     = f'{dataset_hyphened_name}', 
                                        sagemaker_boto_client=sm)

# %% [markdown]
# ### Create trial

# %%
training_trial = Trial.create(trial_name = f'{dataset_hyphened_name}', 
                              experiment_name = training_experiment.experiment_name,
                              sagemaker_boto_client = sm,)
training_trial_comp_name = f'{dataset_hyphened_name}'
experiment_config = {"ExperimentName": training_experiment.experiment_name, 
                       "TrialName": training_trial.trial_name,
                       "TrialComponentDisplayName": training_trial_comp_name}

# %% [markdown]
# ### Run training job & visualize results

# %%
from sagemaker.tensorflow import TensorFlow

dataframe_dir = f's3://obstacles-classification/{train_dataset_name}'

hyperparams={'epochs'       : 30,
             'learning-rate': 0.00015,
             'batch-size'   : 32,
             'optimizer'    : 'adam',
             'dataframe_dir': dataframe_dir
            }

bucket_name = sagemaker_session.default_bucket()
output_path = f's3://{bucket_name}/obstacles_classification/jobs/{train_dataset_name}'

metric_definitions = [
    {'Name': 'auc', 'Regex': 'auc: ([0-9\\.]+)'},
    {'Name': 'recall', 'Regex': 'recall: ([0-9\\.]+)'},
    {'Name': 'specifity', 'Regex': 'specifity: ([0-9\\.]+)'},
    {'Name': 'accuracy', 'Regex': 'accuracy: ([0-9\\.]+)'},
    {'Name': 'loss', 'Regex': 'loss: ([0-9\\.]+)'},
    {'Name': 'validation auc', 'Regex': 'val_auc: ([0-9\\.]+)'},
    {'Name': 'validation recall', 'Regex': 'val_recall: ([0-9\\.]+)'},
    {'Name': 'validation specifity', 'Regex': 'val_specifity: ([0-9\\.]+)'},
    {'Name': 'validation accuracy', 'Regex': 'val_categorical_accuracy: ([0-9\\.]+)'},
    {'Name': 'validation loss', 'Regex': 'val_loss: ([0-9\\.]+)'},
    {'Name': 'test auc', 'Regex': 'test_auc: ([0-9\\.]+)'},
    {'Name': 'test recall', 'Regex': 'test_recall: ([0-9\\.]+)'},
    {'Name': 'test specifity', 'Regex': 'test_specifity: ([0-9\\.]+)'},
    {'Name': 'test accuracy', 'Regex': 'test_accuracy: ([0-9\\.]+)'},
    {'Name': 'test loss', 'Regex': 'test_loss: ([0-9\\.]+)'},
    {'Name': 'epoch', 'Regex': 'Epoch ([0-9]+)'},
]

tf_estimator = TensorFlow(entry_point          = '7_1c_momentum.py', 
                          output_path          = f'{output_path}/',
                          code_location        = output_path,
                          role                 = role,
                          train_instance_count = 1, 
                          train_instance_type  = 'ml.c5.xlarge',
                          framework_version    = '2.3', 
                          py_version           = 'py37',
                          script_mode          = True,
                          metric_definitions   = metric_definitions,
                          debugger_hook_config = False,
                          sagemaker_session    = sagemaker_session,
                          hyperparameters      = hyperparams)

job_name=f'obstacles-classification-{time.strftime("%Y-%m-%d-%H-%M-%S", time.gmtime())}'
training_dataset = f's3://obstacles-classification/{train_dataset_name}/train'
eval_dataset = f's3://obstacles-classification/{train_dataset_name}/eval'
tf_estimator.fit({'training'  : training_dataset,
                  'validation': training_dataset,
                  'eval'      : eval_dataset},   
                  job_name = job_name,
                  experiment_config=experiment_config)
# Out:
# WARNING:sagemaker.deprecations:train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# WARNING:sagemaker.deprecations:train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# WARNING:sagemaker.deprecations:train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# INFO:sagemaker.image_uris:Defaulting to the only supported framework/algorithm version: latest.
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.
# INFO:sagemaker:Creating training-job with name: obstacles-classification-2022-01-13-08-13-34
# 2022-01-13 08:13:34 Starting - Starting the training job...
# 2022-01-13 08:14:02 Starting - Launching requested ML instancesProfilerReport-1642061614: InProgress
# ...
# 2022-01-13 08:14:34 Starting - Preparing the instances for training.........
# 2022-01-13 08:16:03 Downloading - Downloading input data............
# 2022-01-13 08:18:03 Training - Training image download completed. Training in progress..2022-01-13 08:18:03.435970: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2022-01-13 08:18:03.444192: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# 2022-01-13 08:18:03.779051: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2022-01-13 08:18:07,452 sagemaker-training-toolkit INFO     Imported framework sagemaker_tensorflow_container.training
# 2022-01-13 08:18:07,460 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2022-01-13 08:18:07,876 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2022-01-13 08:18:07,891 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2022-01-13 08:18:07,905 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2022-01-13 08:18:07,914 sagemaker-training-toolkit INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "eval": "/opt/ml/input/data/eval",
#         "training": "/opt/ml/input/data/training",
#         "validation": "/opt/ml/input/data/validation"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "batch-size": 32,
#         "learning-rate": 0.00015,
#         "dataframe_dir": "s3://obstacles-classification/7sw_1_5__1",
#         "optimizer": "adam",
#         "model_dir": "s3://sagemaker-eu-west-1-947805154784/obstacles_classification/jobs/7sw_1_5__1/obstacles-classification-2022-01-13-08-13-34/model",
#         "epochs": 30
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "eval": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "validation": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "obstacles-classification-2022-01-13-08-13-34",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-eu-west-1-947805154784/obstacles_classification/jobs/7sw_1_5__1/obstacles-classification-2022-01-13-08-13-34/source/sourcedir.tar.gz",
#     "module_name": "7_1c_momentum",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "7_1c_momentum.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batch-size":32,"dataframe_dir":"s3://obstacles-classification/7sw_1_5__1","epochs":30,"learning-rate":0.00015,"model_dir":"s3://sagemaker-eu-west-1-947805154784/obstacles_classification/jobs/7sw_1_5__1/obstacles-classification-2022-01-13-08-13-34/model","optimizer":"adam"}
# SM_USER_ENTRY_POINT=7_1c_momentum.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"eval":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["eval","training","validation"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=7_1c_momentum
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-eu-west-1-947805154784/obstacles_classification/jobs/7sw_1_5__1/obstacles-classification-2022-01-13-08-13-34/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"eval":"/opt/ml/input/data/eval","training":"/opt/ml/input/data/training","validation":"/opt/ml/input/data/validation"},"current_host":"algo-1","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1"],"hyperparameters":{"batch-size":32,"dataframe_dir":"s3://obstacles-classification/7sw_1_5__1","epochs":30,"learning-rate":0.00015,"model_dir":"s3://sagemaker-eu-west-1-947805154784/obstacles_classification/jobs/7sw_1_5__1/obstacles-classification-2022-01-13-08-13-34/model","optimizer":"adam"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"eval":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"obstacles-classification-2022-01-13-08-13-34","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-eu-west-1-947805154784/obstacles_classification/jobs/7sw_1_5__1/obstacles-classification-2022-01-13-08-13-34/source/sourcedir.tar.gz","module_name":"7_1c_momentum","network_interface_name":"eth0","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"7_1c_momentum.py"}
# SM_USER_ARGS=["--batch-size","32","--dataframe_dir","s3://obstacles-classification/7sw_1_5__1","--epochs","30","--learning-rate","0.00015","--model_dir","s3://sagemaker-eu-west-1-947805154784/obstacles_classification/jobs/7sw_1_5__1/obstacles-classification-2022-01-13-08-13-34/model","--optimizer","adam"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_EVAL=/opt/ml/input/data/eval
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# SM_CHANNEL_VALIDATION=/opt/ml/input/data/validation
# SM_HP_BATCH-SIZE=32
# SM_HP_LEARNING-RATE=0.00015
# SM_HP_DATAFRAME_DIR=s3://obstacles-classification/7sw_1_5__1
# SM_HP_OPTIMIZER=adam
# SM_HP_MODEL_DIR=s3://sagemaker-eu-west-1-947805154784/obstacles_classification/jobs/7sw_1_5__1/obstacles-classification-2022-01-13-08-13-34/model
# SM_HP_EPOCHS=30
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/local/lib/python37.zip:/usr/local/lib/python3.7:/usr/local/lib/python3.7/lib-dynload:/usr/local/lib/python3.7/site-packages
# Invoking script with the following command:
# /usr/local/bin/python3.7 7_1c_momentum.py --batch-size 32 --dataframe_dir s3://obstacles-classification/7sw_1_5__1 --epochs 30 --learning-rate 0.00015 --model_dir s3://sagemaker-eu-west-1-947805154784/obstacles_classification/jobs/7sw_1_5__1/obstacles-classification-2022-01-13-08-13-34/model --optimizer adam
# [2022-01-13 08:18:10.313 ip-10-0-109-72.eu-west-1.compute.internal:28 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2022-01-13 08:18:10.516 ip-10-0-109-72.eu-west-1.compute.internal:28 INFO profiler_config_parser.py:102] User has disabled profiler.
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 200, 200, 3) 0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 200, 200, 3) 0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 200, 200, 1) 0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 200, 200, 7)  0           input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 200, 200, 16) 1024        concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 200, 200, 16) 64          conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 100, 100, 16) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 100, 100, 32) 12832       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 100, 100, 32) 128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 50, 50, 32)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 50, 50, 64)   51264       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 50, 50, 64)   256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 25, 25, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 25, 25, 128)  204928      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 25, 25, 128)  512         conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 13, 13, 128)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 13, 13, 256)  819456      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 13, 13, 256)  1024        conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 4, 4, 256)    0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 4096)         0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 4096)         0           flatten[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1)            4097        dropout[0][0]
# ==================================================================================================
# Total params: 1,095,585
# Trainable params: 1,094,593
# Non-trainable params: 992
# __________________________________________________________________________________________________
# Found 10468 validated image filenames belonging to 2 classes.
# Epoch 1/30
# Found 2616 validated image filenames belonging to 2 classes.
# lr: 0.00024447
# momentum: 0.93020332
# 328/328 - 299s - loss: 158.2948 - auc: 0.7824 - recall: 0.8321 - specifity: 0.4009 - val_loss: 154.8161 - val_auc: 0.8471 - val_recall: 0.0885 - val_specifity: 0.5723
# Epoch 2/30
# lr: 0.00033923
# momentum: 0.92037666
# 328/328 - 305s - loss: 149.0451 - auc: 0.8846 - recall: 0.8740 - specifity: 0.6451 - val_loss: 143.3849 - val_auc: 0.9378 - val_recall: 0.8040 - val_specifity: 0.7855
# Epoch 3/30
# lr: 0.00043398
# momentum: 0.91054994
# 328/328 - 304s - loss: 136.8945 - auc: 0.9256 - recall: 0.8870 - specifity: 0.7580 - val_loss: 129.8253 - val_auc: 0.9615 - val_recall: 0.8860 - val_specifity: 0.8979
# Epoch 4/30
# lr: 0.00052874
# momentum: 0.90072328
# 328/328 - 303s - loss: 122.2214 - auc: 0.9504 - recall: 0.9117 - specifity: 0.8618 - val_loss: 114.0703 - val_auc: 0.9767 - val_recall: 0.9248 - val_specifity: 0.9495
# Epoch 5/30
# lr: 0.00062350
# momentum: 0.89089662
# 328/328 - 302s - loss: 105.6058 - auc: 0.9659 - recall: 0.9274 - specifity: 0.9074 - val_loss: 96.7448 - val_auc: 0.9792 - val_recall: 0.9411 - val_specifity: 0.9379
# Epoch 6/30
# lr: 0.00071825
# momentum: 0.88106996
# 328/328 - 303s - loss: 87.7395 - auc: 0.9766 - recall: 0.9413 - specifity: 0.9425 - val_loss: 78.5194 - val_auc: 0.9919 - val_recall: 0.9277 - val_specifity: 0.9884
# Epoch 7/30
# lr: 0.00081301
# momentum: 0.87124330
# 328/328 - 301s - loss: 69.4486 - auc: 0.9829 - recall: 0.9509 - specifity: 0.9662 - val_loss: 60.5971 - val_auc: 0.9890 - val_recall: 0.7579 - val_specifity: 0.9900
# Epoch 8/30
# lr: 0.00090777
# momentum: 0.86141664
# 328/328 - 300s - loss: 51.6766 - auc: 0.9869 - recall: 0.9560 - specifity: 0.9772 - val_loss: 43.8653 - val_auc: 0.9232 - val_recall: 0.7009 - val_specifity: 0.7510
# Epoch 9/30
# lr: 0.00100253
# momentum: 0.85158998
# 328/328 - 303s - loss: 35.4886 - auc: 0.9884 - recall: 0.9584 - specifity: 0.9819 - val_loss: 28.4308 - val_auc: 0.9671 - val_recall: 0.9239 - val_specifity: 0.8790
# Epoch 10/30
# lr: 0.00109728
# momentum: 0.84176332
# 328/328 - 301s - loss: 22.0923 - auc: 0.9892 - recall: 0.9598 - specifity: 0.9843 - val_loss: 16.6056 - val_auc: 0.9950 - val_recall: 0.8936 - val_specifity: 0.9891
# Epoch 11/30
# lr: 0.00119204
# momentum: 0.83193666
# 328/328 - 303s - loss: 12.9399 - auc: 0.9835 - recall: 0.9512 - specifity: 0.9666 - val_loss: 11.7494 - val_auc: 0.9002 - val_recall: 0.3952 - val_specifity: 0.6964
# Epoch 12/30
# lr: 0.00128680
# momentum: 0.82211000
# 328/328 - 304s - loss: 8.1305 - auc: 0.9769 - recall: 0.9414 - specifity: 0.9550 - val_loss: 6.5120 - val_auc: 0.9853 - val_recall: 0.9936 - val_specifity: 0.9671
# Epoch 13/30
# lr: 0.00138155
# momentum: 0.81228334
# 328/328 - 303s - loss: 5.1687 - auc: 0.9788 - recall: 0.9476 - specifity: 0.9552 - val_loss: 4.7719 - val_auc: 0.9389 - val_recall: 0.5797 - val_specifity: 0.7454
# Epoch 14/30
# lr: 0.00147631
# momentum: 0.80245668
# 328/328 - 308s - loss: 3.5366 - auc: 0.9827 - recall: 0.9576 - specifity: 0.9649 - val_loss: 6.4432 - val_auc: 0.4919 - val_recall: 0.9873 - val_specifity: 0.2226
# Epoch 15/30
# lr: 0.00142922
# momentum: 0.80734003
# 328/328 - 306s - loss: 2.7476 - auc: 0.9791 - recall: 0.9545 - specifity: 0.9537 - val_loss: 3.8514 - val_auc: 0.5908 - val_recall: 0.6104 - val_specifity: 0.2062
# Epoch 16/30
# lr: 0.00133446
# momentum: 0.81716669
# 328/328 - 306s - loss: 2.2004 - auc: 0.9806 - recall: 0.9571 - specifity: 0.9595 - val_loss: 2.2796 - val_auc: 0.9231 - val_recall: 0.9530 - val_specifity: 0.8203
# Epoch 17/30
# lr: 0.00123971
# momentum: 0.82699335
# 328/328 - 305s - loss: 1.8167 - auc: 0.9873 - recall: 0.9591 - specifity: 0.9748 - val_loss: 1.6594 - val_auc: 0.9915 - val_recall: 0.9581 - val_specifity: 0.9768
# Epoch 18/30
# lr: 0.00114495
# momentum: 0.83682001
# 328/328 - 305s - loss: 1.7122 - auc: 0.9848 - recall: 0.9593 - specifity: 0.9742 - val_loss: 2.6808 - val_auc: 0.9279 - val_recall: 0.5167 - val_specifity: 0.7358
# Epoch 19/30
# lr: 0.00105019
# momentum: 0.84664667
# 328/328 - 307s - loss: 1.5318 - auc: 0.9896 - recall: 0.9631 - specifity: 0.9847 - val_loss: 1.7513 - val_auc: 0.9715 - val_recall: 0.8347 - val_specifity: 0.9238
# Epoch 20/30
# lr: 0.00095544
# momentum: 0.85647339
# 328/328 - 305s - loss: 1.4716 - auc: 0.9867 - recall: 0.9629 - specifity: 0.9744 - val_loss: 18.8934 - val_auc: 0.6204 - val_recall: 0.9865 - val_specifity: 0.2954
# Epoch 21/30
# lr: 0.00086068
# momentum: 0.86630005
# 328/328 - 306s - loss: 1.4620 - auc: 0.9893 - recall: 0.9650 - specifity: 0.9821 - val_loss: 1.3881 - val_auc: 0.9948 - val_recall: 0.9943 - val_specifity: 0.9943
# Epoch 22/30
# lr: 0.00076592
# momentum: 0.87612671
# 328/328 - 306s - loss: 1.2157 - auc: 0.9940 - recall: 0.9734 - specifity: 0.9903 - val_loss: 1.5241 - val_auc: 0.9612 - val_recall: 0.8978 - val_specifity: 0.8895
# Epoch 23/30
# lr: 0.00067116
# momentum: 0.88595337
# 328/328 - 308s - loss: 1.1288 - auc: 0.9944 - recall: 0.9756 - specifity: 0.9922 - val_loss: 1.1595 - val_auc: 0.9969 - val_recall: 0.8811 - val_specifity: 0.9983
# Epoch 24/30
# lr: 0.00057641
# momentum: 0.89578003
# 328/328 - 307s - loss: 1.0277 - auc: 0.9959 - recall: 0.9775 - specifity: 0.9955 - val_loss: 1.4801 - val_auc: 0.9183 - val_recall: 0.8449 - val_specifity: 0.7563
# Epoch 25/30
# lr: 0.00048165
# momentum: 0.90560669
# 328/328 - 307s - loss: 1.0047 - auc: 0.9949 - recall: 0.9766 - specifity: 0.9938 - val_loss: 1.0194 - val_auc: 0.9952 - val_recall: 0.9419 - val_specifity: 0.9959
# Epoch 26/30
# lr: 0.00038689
# momentum: 0.91543335
# 328/328 - 306s - loss: 0.9097 - auc: 0.9973 - recall: 0.9803 - specifity: 0.9968 - val_loss: 0.8712 - val_auc: 0.9966 - val_recall: 0.9860 - val_specifity: 0.9966
# Epoch 27/30
# lr: 0.00029214
# momentum: 0.92526001
# 328/328 - 307s - loss: 0.8696 - auc: 0.9974 - recall: 0.9827 - specifity: 0.9959 - val_loss: 0.9273 - val_auc: 0.9905 - val_recall: 0.9607 - val_specifity: 0.9815
# Epoch 28/30
# lr: 0.00015000
# momentum: 0.94000000
# 328/328 - 308s - loss: 0.8084 - auc: 0.9971 - recall: 0.9842 - specifity: 0.9972 - val_loss: 0.7751 - val_auc: 0.9975 - val_recall: 0.9820 - val_specifity: 0.9992
# Found 1455 images belonging to 2 classes.
# #015  1/300 [..............................] - ETA: 0s - loss: 0.7553 - auc: 1.0000 - recall: 1.0000 - specifity: 1.0000#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015  2/300 [..............................] - ETA: 50s - loss: 0.7640 - auc: 1.0000 - recall: 0.9737 - specifity: 1.0000#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015  3/300 [..............................] - ETA: 1:17 - loss: 0.7712 - auc: 0.9991 - recall: 0.9600 - specifity: 1.0000#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015  4/300 [..............................] - ETA: 1:21 - loss: 0.7667 - auc: 0.9993 - recall: 0.9714 - specifity: 1.0000#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015  5/300 [..............................] - ETA: 1:25 - loss: 0.7594 - auc: 0.9995 - recall: 0.9789 - specifity: 1.0000#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015  6/300 [..............................] - ETA: 1:26 - loss: 0.7683 - auc: 0.9990 - recall: 0.9737 - specifity: 1.0000#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015  7/300 [..............................] - ETA: 1:27 - loss: 0.7662 - auc: 0.9992 - recall: 0.9778 - specifity: 1.0000#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010# ...
# ...] - ETA: 1:15 - loss: 0.7715 - auc: 0.9977 - recall: 0.9871 - specifity: 0.9959#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 71/300 [======>.......................] - ETA: 1:15 - loss: 0.7710 - auc: 0.9977 - recall: 0.9873 - specifity: 0.9960#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 72/300 [======>.......................] - ETA: 1:15 - loss: 0.7710 - auc: 0.9977 - recall: 0.9867 - specifity: 0.9960#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 73/300 [======>.......................] - ETA: 1:14 - loss: 0.7705 - auc: 0.9978 - recall: 0.9869 - specifity: 0.9961#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 74/300 [======>.......................] - ETA: 1:14 - loss: 0.7705 - auc: 0.9978 - recall: 0.9871 - specifity: 0.9961#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 75/300 [======>.......................] - ETA: 1:14 - loss: 0.7703 - auc: 0.9978 - recall: 0.9873 - specifity: 0.9962#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015 76/300 [======>.......................] - ETA: 1:14 - loss: 0.7698 - auc: 0.9978 - recall: 0.9875 - specifity: 0.9962#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#0 ...
# ifity: 0.9964#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015140/300 [=============>................] - ETA: 53s - loss: 0.7736 - auc: 0.9972 - recall: 0.9839 - specifity: 0.9964#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015141/300 [=============>................] - ETA: 52s - loss: 0.7736 - auc: 0.9972 - recall: 0.9840 - specifity: 0.9964#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015142/300 [=============>................] - ETA: 52s - loss: 0.7735 - auc: 0.9972 - recall: 0.9841 - specifity: 0.9965#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015143/300 [=============>................] - ETA: 52s - loss: 0.7732 - auc: 0.9973 - recall: 0.9842 - specifity: 0.9965#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015144/300 [=============>................] - ETA: 51s - loss: 0.7733 - auc: 0.9973 - recall: 0.9839 - specifity: 0.9965#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015145/300 [=============>................] - ETA: 51s - loss: 0.7730 - auc: 0.9973 - recall: 0.9840 - specifity: 0.9965#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010# ...
# .] - ETA: 30s - loss: 0.7732 - auc: 0.9972 - recall: 0.9830 - specifity: 0.9969#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015210/300 [====================>.........] - ETA: 29s - loss: 0.7730 - auc: 0.9972 - recall: 0.9831 - specifity: 0.9969#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015211/300 [====================>.........] - ETA: 29s - loss: 0.7730 - auc: 0.9972 - recall: 0.9832 - specifity: 0.9969#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015212/300 [====================>.........] - ETA: 29s - loss: 0.7733 - auc: 0.9972 - recall: 0.9833 - specifity: 0.9969#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015213/300 [====================>.........] - ETA: 28s - loss: 0.7732 - auc: 0.9972 - recall: 0.9833 - specifity: 0.9970#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015214/300 [====================>.........] - ETA: 28s - loss: 0.7734 - auc: 0.9972 - recall: 0.9831 - specifity: 0.9970#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015215/300 [====================>.........] - ETA: 28s - loss: 0.7732 - auc: 0.9972 - recall: 0.9832 - specifity: 0.9970#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#01 ...
# #010#010#010#010#010#010#010#010#010#010#015279/300 [==========================>...] - ETA: 6s - loss: 0.7731 - auc: 0.9973 - recall: 0.9840 - specifity: 0.9969#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015280/300 [===========================>..] - ETA: 6s - loss: 0.7730 - auc: 0.9973 - recall: 0.9841 - specifity: 0.9969#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015281/300 [===========================>..] - ETA: 6s - loss: 0.7729 - auc: 0.9973 - recall: 0.9841 - specifity: 0.9969#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015282/300 [===========================>..] - ETA: 5s - loss: 0.7728 - auc: 0.9973 - recall: 0.9840 - specifity: 0.9969#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015283/300 [===========================>..] - ETA: 5s - loss: 0.7731 - auc: 0.9973 - recall: 0.9836 - specifity: 0.9970#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015284/300 [===========================>..] - ETA: 5s - loss: 0.7730 - auc: 0.9973 - recall: 0.9837 - specifity: 0.9970#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015285/300 [===========================>..] - ETA: 4s - loss: 0.7729 - auc: 0.9973 - recall: 0.9838 - specifity: 0.9970#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010 ...
# test_auc: 0.9971450567245483
# test_recall: 0.9836527705192566
# test_specifity: 0.9968869686126709
# 2022-01-13 08:18:08.229970: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2022-01-13 08:18:08.230097: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# 2022-01-13 08:18:08.257064: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# 2022-01-13 08:23:11.027485: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From /usr/local/lib/python3.7/site-packages/tensorflow/python/training/tracking/tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: s3://obstacles-classification-model-checkpoints/7sw_1_5__1/2022-01-13-08-18-10/epoch-1/assets
# INFO:tensorflow:Assets written to: s3://obstacles-classification-model-checkpoints/7sw_1_5__1/2022-01-13-08-18-10/epoch-1/assets
# INFO:tensorflow:Assets written to: s3://obstacles-classification-model-checkpoints/7sw_1_5__1/2022-01-13-08-18-10/epoch-2/assets
# INFO:tensorflow:Assets written to: s3://obstacles-classification-model-checkpoints/7sw_1_5__1/2022-01-13-08-18-10/epoch-2/assets
# INFO:tensorflow:Assets written to: s3://obstacles-classification-model-checkpoints/7sw_1_5__1/2022-01-13-08-18-10/epoch-3/assets
# INFO:tensorflow:Assets written to: s3://obstacles-classification-model-checkpoints/7sw_1_5__1/2022-01-13-08-18-10/epoch-3/assets
# INFO:tensorflow:Assets written to: s3://obstacles-classification-model-checkpoints/7sw_1_5__1/2022-01-13-08-18-10/epoch-4/assets
# INFO:tensorflow:Assets written to: s3://obstacles-classification-model-checkpoints/7sw_1_5__1/2022-01-13-08-18-10/epoch-4/assets
# INFO:tensorflow:Assets written to: s3://obstacles-classification-model-checkpoints/7sw_1_5__1/2022-01-13-08-18-10/epoch-5/assets
# INFO:tensorflow:Assets written to: s3://obstacles-classification-model-checkpoints/7sw_1_5__1/2022-01-13-08-18-10/epoch-5/assets
# INFO:tensorflow:Assets written to: s3://obstacles-classification-model-checkpoints/7sw_1_5__1/2022-01-13-08-18-10/epoch-6/assets
# INFO:tensorflow:Assets written to: s3://obstacles-classification-model-checkpoints/7sw_1_5__1/2022-01-13-08-18-10/epoch-6/assets
# INFO:tensorflow:Assets written to: s3://obstacles-classification-model-checkpoints/7sw_1_5__1/2022-01-13-08-18-10/epoch-7/assets
# INFO:tensorflow:Assets written to: s3://obstacles-classification-model-checkpoints/7sw_1_5__1/2022-01-13-08-18-10/epoch-7/assets
# INFO:tensorflow:Assets written to: s3://obstacles-classification-model-checkpoints/7sw_1_5__1/2022-01-13-08-18-10/epoch-8/assets
# INFO:tensorflow:Assets written to: s3://obstacles-classification-model-checkpoints/7sw_1_5__1/2022-01-13-08-18-10/epoch-8/assets
# INFO:tensorflow:Assets written to: s3://obstacles-classification-model-checkpoints/7sw_1_5__1/2022-01-13-08-18-10/epoch-9/assets
# INFO:tensorflow:Assets written to: s3://obstacles-classification-model-checkpoints/7sw_1_5__1/2022-01-13-08-18-10/epoch-9/assets
# INFO:tensorflow:Assets written to: s3://obstacles-classification-model-checkpoints/7sw_1_5__1/2022-01-13-08-18-10/epoch-10/assets
# INFO:tensorflow:Assets written to: s3://obstacles-classification-model-checkpoints/7sw_1_5__1/2022-01-13-08-18-10/epoch-10/assets
# INFO:tensorflow:Assets written to: s3://obstacles-classification-model-checkpoints/7sw_1_5__1/2022-01-13-08-18-10/epoch-11/assets
# INFO:tensorflow:Assets written to: s3://obstacles-classification-model-checkpoints/7sw_1_5__1/2022-01-13-08-18-10/epoch-11/assets
# INFO:tensorflow:Assets written to: s3://obstacles-classification-model-checkpoints/7sw_1_5__1/2022-01-13-08-18-10/epoch-12/assets
# INFO:tensorflow:Assets written to: s3://obstacles-classification-model-checkpoints/7sw_1_5__1/2022-01-13-08-18-10/epoch-12/assets
# INFO:tensorflow:Assets written to: s3://obstacles-classification-model-checkpoints/7sw_1_5__1/2022-01-13-08-18-10/epoch-13/assets
# INFO:tensorflow:Assets written to: s3://obstacles-classification-model-checkpoints/7sw_1_5__1/2022-01-13-08-18-10/epoch-13/assets
# INFO:tensorflow:Assets written to: s3://obstacles-classification-model-checkpoints/7sw_1_5__1/2022-01-13-08-18-10/epoch-14/assets
# INFO:tensorflow:Assets written to: s3://obstacles-classification-model-checkpoints/7sw_1_5__1/2022-01-13-08-18-10/epoch-14/assets
# INFO:tensorflow:Assets written to: s3://obstacles-classification-model-checkpoints/7sw_1_5__1/2022-01-13-08-18-10/epoch-15/assets
# INFO:tensorflow:Assets written to: s3://obstacles-classification-model-checkpoints/7sw_1_5__1/2022-01-13-08-18-10/epoch-15/assets
# INFO:tensorflow:Assets written to: s3://obstacles-classification-model-checkpoints/7sw_1_5__1/2022-01-13-08-18-10/epoch-16/assets
# INFO:tensorflow:Assets written to: s3://obstacles-classification-model-checkpoints/7sw_1_5__1/2022-01-13-08-18-10/epoch-16/assets
# INFO:tensorflow:Assets written to: s3://obstacles-classification-model-checkpoints/7sw_1_5__1/2022-01-13-08-18-10/epoch-17/assets
# INFO:tensorflow:Assets written to: s3://obstacles-classification-model-checkpoints/7sw_1_5__1/2022-01-13-08-18-10/epoch-17/assets
# INFO:tensorflow:Assets written to: s3://obstacles-classification-model-checkpoints/7sw_1_5__1/2022-01-13-08-18-10/epoch-18/assets
# INFO:tensorflow:Assets written to: s3://obstacles-classification-model-checkpoints/7sw_1_5__1/2022-01-13-08-18-10/epoch-18/assets
# INFO:tensorflow:Assets written to: s3://obstacles-classification-model-checkpoints/7sw_1_5__1/2022-01-13-08-18-10/epoch-19/assets
# INFO:tensorflow:Assets written to: s3://obstacles-classification-model-checkpoints/7sw_1_5__1/2022-01-13-08-18-10/epoch-19/assets
# INFO:tensorflow:Assets written to: s3://obstacles-classification-model-checkpoints/7sw_1_5__1/2022-01-13-08-18-10/epoch-20/assets
# INFO:tensorflow:Assets written to: s3://obstacles-classification-model-checkpoints/7sw_1_5__1/2022-01-13-08-18-10/epoch-20/assets
# INFO:tensorflow:Assets written to: s3://obstacles-classification-model-checkpoints/7sw_1_5__1/2022-01-13-08-18-10/epoch-21/assets
# INFO:tensorflow:Assets written to: s3://obstacles-classification-model-checkpoints/7sw_1_5__1/2022-01-13-08-18-10/epoch-21/assets
# INFO:tensorflow:Assets written to: s3://obstacles-classification-model-checkpoints/7sw_1_5__1/2022-01-13-08-18-10/epoch-22/assets
# INFO:tensorflow:Assets written to: s3://obstacles-classification-model-checkpoints/7sw_1_5__1/2022-01-13-08-18-10/epoch-22/assets
# INFO:tensorflow:Assets written to: s3://obstacles-classification-model-checkpoints/7sw_1_5__1/2022-01-13-08-18-10/epoch-23/assets
# INFO:tensorflow:Assets written to: s3://obstacles-classification-model-checkpoints/7sw_1_5__1/2022-01-13-08-18-10/epoch-23/assets
# INFO:tensorflow:Assets written to: s3://obstacles-classification-model-checkpoints/7sw_1_5__1/2022-01-13-08-18-10/epoch-24/assets
# INFO:tensorflow:Assets written to: s3://obstacles-classification-model-checkpoints/7sw_1_5__1/2022-01-13-08-18-10/epoch-24/assets
# INFO:tensorflow:Assets written to: s3://obstacles-classification-model-checkpoints/7sw_1_5__1/2022-01-13-08-18-10/epoch-25/assets
# INFO:tensorflow:Assets written to: s3://obstacles-classification-model-checkpoints/7sw_1_5__1/2022-01-13-08-18-10/epoch-25/assets
# INFO:tensorflow:Assets written to: s3://obstacles-classification-model-checkpoints/7sw_1_5__1/2022-01-13-08-18-10/epoch-26/assets
# INFO:tensorflow:Assets written to: s3://obstacles-classification-model-checkpoints/7sw_1_5__1/2022-01-13-08-18-10/epoch-26/assets
# INFO:tensorflow:Assets written to: s3://obstacles-classification-model-checkpoints/7sw_1_5__1/2022-01-13-08-18-10/epoch-27/assets
# INFO:tensorflow:Assets written to: s3://obstacles-classification-model-checkpoints/7sw_1_5__1/2022-01-13-08-18-10/epoch-27/assets
# INFO:tensorflow:Assets written to: s3://obstacles-classification-model-checkpoints/7sw_1_5__1/2022-01-13-08-18-10/epoch-28/assets
# INFO:tensorflow:Assets written to: s3://obstacles-classification-model-checkpoints/7sw_1_5__1/2022-01-13-08-18-10/epoch-28/assets
# INFO:tensorflow:Assets written to: s3://obstacles-classification-model-checkpoints/7sw_1_5__1/2022-01-13-08-18-10/epoch-29/assets
# INFO:tensorflow:Assets written to: s3://obstacles-classification-model-checkpoints/7sw_1_5__1/2022-01-13-08-18-10/epoch-29/assets
# INFO:tensorflow:Assets written to: s3://obstacles-classification-model-checkpoints/7sw_1_5__1/2022-01-13-08-18-10/epoch-30/assets
# INFO:tensorflow:Assets written to: s3://obstacles-classification-model-checkpoints/7sw_1_5__1/2022-01-13-08-18-10/epoch-30/assets
# WARNING:tensorflow:From 7_1c_momentum.py:290: Model.evaluate_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.evaluate, which supports generators.
# WARNING:tensorflow:From 7_1c_momentum.py:290: Model.evaluate_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.evaluate, which supports generators.
# INFO:tensorflow:Assets written to: /opt/ml/model/0113105240/assets
# INFO:tensorflow:Assets written to: /opt/ml/model/0113105240/assets
# 2022-01-13 10:52:44,301 sagemaker-training-toolkit INFO     Reporting training SUCCESS
#
# 2022-01-13 10:52:56 Uploading - Uploading generated training model
# 2022-01-13 10:52:56 Completed - Training job completed
# Training seconds: 9423
# Billable seconds: 9423
