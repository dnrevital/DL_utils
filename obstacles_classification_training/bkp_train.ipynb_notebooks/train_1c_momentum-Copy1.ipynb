# %%
import time

train_dataset_name = '7sw_1_5__1'
eval_dataset_name = '7sw_1_5__1'
dataset_hyphened_name = train_dataset_name.replace('_', '-') + '-' + f'{time.strftime("%Y-%m-%d-%H-%M-%S", time.gmtime())}'
layers = 5

# %% [markdown]
# ### Client & SM sessions

# %%
import sagemaker, boto3

sess = boto3.Session()
sm   = sess.client('sagemaker')
role = sagemaker.get_execution_role()
sagemaker_session = sagemaker.Session(boto_session=sess)

# %% [markdown]
# ### Create experiment

# %%
from smexperiments.experiment import Experiment
from smexperiments.trial import Trial
from smexperiments.trial_component import TrialComponent

training_experiment = Experiment.create(experiment_name = f'{dataset_hyphened_name}', 
                                        description     = f'{dataset_hyphened_name}', 
                                        sagemaker_boto_client=sm)

# %% [markdown]
# ### Create trial

# %%
training_trial = Trial.create(trial_name = f'{dataset_hyphened_name}', 
                              experiment_name = training_experiment.experiment_name,
                              sagemaker_boto_client = sm,)
training_trial_comp_name = f'{dataset_hyphened_name}'
experiment_config = {"ExperimentName": training_experiment.experiment_name, 
                       "TrialName": training_trial.trial_name,
                       "TrialComponentDisplayName": training_trial_comp_name}

# %% [markdown]
# ### Run training job & visualize results

# %%
from sagemaker.tensorflow import TensorFlow

dataframe_dir = f's3://obstacles-classification/{train_dataset_name}'

hyperparams={'epochs'       : 30,
             'learning-rate': 0.00015,
             'batch-size'   : 32,
             'optimizer'    : 'adam',
             'dataframe_dir': dataframe_dir
            }

bucket_name = sagemaker_session.default_bucket()
output_path = f's3://{bucket_name}/obstacles_classification/jobs/{train_dataset_name}'

metric_definitions = [
    {'Name': 'auc', 'Regex': 'auc: ([0-9\\.]+)'},
    {'Name': 'recall', 'Regex': 'recall: ([0-9\\.]+)'},
    {'Name': 'specifity', 'Regex': 'specifity: ([0-9\\.]+)'},
    {'Name': 'accuracy', 'Regex': 'accuracy: ([0-9\\.]+)'},
    {'Name': 'loss', 'Regex': 'loss: ([0-9\\.]+)'},
    {'Name': 'validation auc', 'Regex': 'val_auc: ([0-9\\.]+)'},
    {'Name': 'validation recall', 'Regex': 'val_recall: ([0-9\\.]+)'},
    {'Name': 'validation specifity', 'Regex': 'val_specifity: ([0-9\\.]+)'},
    {'Name': 'validation accuracy', 'Regex': 'val_categorical_accuracy: ([0-9\\.]+)'},
    {'Name': 'validation loss', 'Regex': 'val_loss: ([0-9\\.]+)'},
    {'Name': 'test auc', 'Regex': 'test_auc: ([0-9\\.]+)'},
    {'Name': 'test recall', 'Regex': 'test_recall: ([0-9\\.]+)'},
    {'Name': 'test specifity', 'Regex': 'test_specifity: ([0-9\\.]+)'},
    {'Name': 'test accuracy', 'Regex': 'test_accuracy: ([0-9\\.]+)'},
    {'Name': 'test loss', 'Regex': 'test_loss: ([0-9\\.]+)'},
    {'Name': 'epoch', 'Regex': 'Epoch ([0-9]+)'},
]

tf_estimator = TensorFlow(entry_point          = '7_channels_weights_1_cycle_lr.py', 
                          output_path          = f'{output_path}/',
                          code_location        = output_path,
                          role                 = role,
                          train_instance_count = 1, 
                          train_instance_type  = 'ml.c5.xlarge',
                          framework_version    = '2.3', 
                          py_version           = 'py37',
                          script_mode          = True,
                          metric_definitions   = metric_definitions,
                          debugger_hook_config = False,
                          sagemaker_session    = sagemaker_session,
                          hyperparameters      = hyperparams)

job_name=f'obstacles-classification-{time.strftime("%Y-%m-%d-%H-%M-%S", time.gmtime())}'
training_dataset = f's3://obstacles-classification/{train_dataset_name}/train'
eval_dataset = f's3://obstacles-classification/{train_dataset_name}/eval'
tf_estimator.fit({'training'  : training_dataset,
                  'validation': training_dataset,
                  'eval'      : eval_dataset},   
                  job_name = job_name,
                  experiment_config=experiment_config)
# Out:
# WARNING:sagemaker.deprecations:train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# WARNING:sagemaker.deprecations:train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# WARNING:sagemaker.deprecations:train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# INFO:sagemaker.image_uris:Defaulting to the only supported framework/algorithm version: latest.
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.
# INFO:sagemaker:Creating training-job with name: obstacles-classification-2022-01-12-15-27-59
# 2022-01-12 15:28:00 Starting - Starting the training job...
# 2022-01-12 15:28:24 Starting - Launching requested ML instancesProfilerReport-1642001279: InProgress
# ...
# 2022-01-12 15:28:57 Starting - Preparing the instances for training.........
# 2022-01-12 15:30:24 Downloading - Downloading input data.........
# 2022-01-12 15:32:00 Training - Downloading the training image...
# 2022-01-12 15:32:25 Training - Training image download completed. Training in progress.2022-01-12 15:32:17.406409: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2022-01-12 15:32:17.413892: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# 2022-01-12 15:32:17.708136: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2022-01-12 15:32:20,951 sagemaker-training-toolkit INFO     Imported framework sagemaker_tensorflow_container.training
# 2022-01-12 15:32:20,958 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2022-01-12 15:32:21,416 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2022-01-12 15:32:21,432 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2022-01-12 15:32:21,447 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2022-01-12 15:32:21,457 sagemaker-training-toolkit INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "eval": "/opt/ml/input/data/eval",
#         "training": "/opt/ml/input/data/training",
#         "validation": "/opt/ml/input/data/validation"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "batch-size": 32,
#         "learning-rate": 0.00015,
#         "dataframe_dir": "s3://obstacles-classification/7sw_1_5__1",
#         "optimizer": "adam",
#         "model_dir": "s3://sagemaker-eu-west-1-947805154784/obstacles_classification/jobs/7sw_1_5__1/obstacles-classification-2022-01-12-15-27-59/model",
#         "epochs": 30
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "eval": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "validation": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "obstacles-classification-2022-01-12-15-27-59",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-eu-west-1-947805154784/obstacles_classification/jobs/7sw_1_5__1/obstacles-classification-2022-01-12-15-27-59/source/sourcedir.tar.gz",
#     "module_name": "7_channels_weights_1_cycle_lr",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "7_channels_weights_1_cycle_lr.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batch-size":32,"dataframe_dir":"s3://obstacles-classification/7sw_1_5__1","epochs":30,"learning-rate":0.00015,"model_dir":"s3://sagemaker-eu-west-1-947805154784/obstacles_classification/jobs/7sw_1_5__1/obstacles-classification-2022-01-12-15-27-59/model","optimizer":"adam"}
# SM_USER_ENTRY_POINT=7_channels_weights_1_cycle_lr.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"eval":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["eval","training","validation"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=7_channels_weights_1_cycle_lr
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-eu-west-1-947805154784/obstacles_classification/jobs/7sw_1_5__1/obstacles-classification-2022-01-12-15-27-59/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"eval":"/opt/ml/input/data/eval","training":"/opt/ml/input/data/training","validation":"/opt/ml/input/data/validation"},"current_host":"algo-1","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1"],"hyperparameters":{"batch-size":32,"dataframe_dir":"s3://obstacles-classification/7sw_1_5__1","epochs":30,"learning-rate":0.00015,"model_dir":"s3://sagemaker-eu-west-1-947805154784/obstacles_classification/jobs/7sw_1_5__1/obstacles-classification-2022-01-12-15-27-59/model","optimizer":"adam"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"eval":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"obstacles-classification-2022-01-12-15-27-59","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-eu-west-1-947805154784/obstacles_classification/jobs/7sw_1_5__1/obstacles-classification-2022-01-12-15-27-59/source/sourcedir.tar.gz","module_name":"7_channels_weights_1_cycle_lr","network_interface_name":"eth0","num_cpus":4,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"7_channels_weights_1_cycle_lr.py"}
# SM_USER_ARGS=["--batch-size","32","--dataframe_dir","s3://obstacles-classification/7sw_1_5__1","--epochs","30","--learning-rate","0.00015","--model_dir","s3://sagemaker-eu-west-1-947805154784/obstacles_classification/jobs/7sw_1_5__1/obstacles-classification-2022-01-12-15-27-59/model","--optimizer","adam"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_EVAL=/opt/ml/input/data/eval
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# SM_CHANNEL_VALIDATION=/opt/ml/input/data/validation
# SM_HP_BATCH-SIZE=32
# SM_HP_LEARNING-RATE=0.00015
# SM_HP_DATAFRAME_DIR=s3://obstacles-classification/7sw_1_5__1
# SM_HP_OPTIMIZER=adam
# SM_HP_MODEL_DIR=s3://sagemaker-eu-west-1-947805154784/obstacles_classification/jobs/7sw_1_5__1/obstacles-classification-2022-01-12-15-27-59/model
# SM_HP_EPOCHS=30
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/local/lib/python37.zip:/usr/local/lib/python3.7:/usr/local/lib/python3.7/lib-dynload:/usr/local/lib/python3.7/site-packages
# Invoking script with the following command:
# /usr/local/bin/python3.7 7_channels_weights_1_cycle_lr.py --batch-size 32 --dataframe_dir s3://obstacles-classification/7sw_1_5__1 --epochs 30 --learning-rate 0.00015 --model_dir s3://sagemaker-eu-west-1-947805154784/obstacles_classification/jobs/7sw_1_5__1/obstacles-classification-2022-01-12-15-27-59/model --optimizer adam
# [2022-01-12 15:32:23.940 ip-10-0-71-237.eu-west-1.compute.internal:27 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [2022-01-12 15:32:24.133 ip-10-0-71-237.eu-west-1.compute.internal:27 INFO profiler_config_parser.py:102] User has disabled profiler.
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 200, 200, 3) 0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 200, 200, 3) 0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 200, 200, 1) 0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 200, 200, 7)  0           input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 200, 200, 16) 1024        concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 200, 200, 16) 64          conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 100, 100, 16) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 100, 100, 32) 12832       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 100, 100, 32) 128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 50, 50, 32)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 50, 50, 64)   51264       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 50, 50, 64)   256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 25, 25, 64)   0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 25, 25, 128)  204928      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 25, 25, 128)  512         conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 13, 13, 128)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 13, 13, 256)  819456      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 13, 13, 256)  1024        conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 4, 4, 256)    0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 4096)         0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 4096)         0           flatten[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1)            4097        dropout[0][0]
# ==================================================================================================
# Total params: 1,095,585
# Trainable params: 1,094,593
# Non-trainable params: 992
# __________________________________________________________________________________________________
# Found 10468 validated image filenames belonging to 2 classes.
# Epoch 1/30
# Found 2616 validated image filenames belonging to 2 classes.
# lr: 0.00024447
# 328/328 - 297s - loss: 63.1257 - auc: 0.9365 - recall: 0.9032 - specifity: 0.8021 - val_loss: 18.4137 - val_auc: 0.7595 - val_recall: 0.0000e+00 - val_specifity: 0.3630
# Epoch 2/30
