# %% [markdown]
# ## Imports

# %%
import cv2
import os
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ## Settings

# %%
src_dir = '/home/drevital/obstacles_classification_datasets/v10_test/fn'
dst_dir = '/home/drevital/obstacles_classification_datasets/v10_test/fn_no_mask'
#obs_src_dir = os.path.join(src_dir, 'obstacle')
obs_src_dir = src_dir
#no_obs_src_dir = os.path.join(src_dir, 'no_obstacle')
no_obs_src_dir = src_dir
#obs_dst_dir = os.path.join(dst_dir, 'obstacle')
obs_dst_dir = dst_dir
#no_obs_dst_dir = os.path.join(dst_dir, 'no_obstacle')
no_obs_dst_dir = dst_dir

# %% [markdown]
# ## Function to remove mask images and store fixed image

# %%
def remove_masks(src_dir, dst_dir):
    im_fnames = os.listdir(src_dir)
    for im_fname in im_fnames:
        src_path = os.path.join(src_dir, im_fname)
        im = cv2.imread(src_path)
        #im = cv2.cvtColor(imrgb, cv2.COLOR_BGR2RGB)        
        w = im.shape[1]
        ref = im[:, :w//3]
        current = im[:, w//3:(w*2)//3] 
        mask = im[:, (w*2)//3:] 
        no_mask = cv2.hconcat([ref, current])
        dst_path = os.path.join(dst_dir, im_fname)
        print(f'dst_path: {dst_path}')
        cv2.imwrite(dst_path, no_mask)

# %%
remove_masks(obs_src_dir, obs_dst_dir)
remove_masks(no_obs_src_dir, no_obs_dst_dir)
# Out:
# dst_path: /home/drevital/obstacles_classification_datasets/v10_test/fn_no_mask/1015_obstacles_0.41_classification_2022-09-01T14-47-44_0.99.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/v10_test/fn_no_mask/1323_obstacles_0.06_classification_2022-09-01T14-47-45_0.96.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/v10_test/fn_no_mask/1350_obstacles_0.45_classification_2022-09-01T14-47-45_0.99.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/v10_test/fn_no_mask/1183_obstacles_0.17_classification_2022-09-01T14-47-45_0.98.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/v10_test/fn_no_mask/1227_obstacles_0.45_classification_2022-09-01T14-47-45_0.97.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/v10_test/fn_no_mask/871_obstacles_0.29_classification_2022-09-01T14-07-05_0.80.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/v10_test/fn_no_mask/1271_obstacles_0.13_classification_2022-09-01T14-47-45_0.88.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/v10_test/fn_no_mask/925_obstacles_0.42_classification_2022-09-01T14-07-05_0.87.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/v10_test/fn_no_mask/1153_obstacles_0.26_classification_2022-09-01T14-47-44_0.97.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/v10_test/fn_no_mask/6227_obstacles_0.29_classification_2022-09-01T14-23-49_0.54.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/v10_test/fn_no_mask/1061_obstacles_0.45_classification_2022-09-01T14-47-44_0.92.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/v10_test/fn_no_mask/1279_obstacles_0.10_classification_2022-09-01T14-47-45_0.84.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/v10_test/fn_no_mask/1015_obstacles_0.41_classification_2022-09-01T14-47-44_0.99.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/v10_test/fn_no_mask/1323_obstacles_0.06_classification_2022-09-01T14-47-45_0.96.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/v10_test/fn_no_mask/1350_obstacles_0.45_classification_2022-09-01T14-47-45_0.99.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/v10_test/fn_no_mask/1183_obstacles_0.17_classification_2022-09-01T14-47-45_0.98.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/v10_test/fn_no_mask/1227_obstacles_0.45_classification_2022-09-01T14-47-45_0.97.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/v10_test/fn_no_mask/871_obstacles_0.29_classification_2022-09-01T14-07-05_0.80.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/v10_test/fn_no_mask/1271_obstacles_0.13_classification_2022-09-01T14-47-45_0.88.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/v10_test/fn_no_mask/925_obstacles_0.42_classification_2022-09-01T14-07-05_0.87.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/v10_test/fn_no_mask/1153_obstacles_0.26_classification_2022-09-01T14-47-44_0.97.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/v10_test/fn_no_mask/6227_obstacles_0.29_classification_2022-09-01T14-23-49_0.54.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/v10_test/fn_no_mask/1061_obstacles_0.45_classification_2022-09-01T14-47-44_0.92.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/v10_test/fn_no_mask/1279_obstacles_0.10_classification_2022-09-01T14-47-45_0.84.jpg

# %%
20.95/11.76
# Out:
# 1.7814625850340136

# %%
10/1.78
# Out:
# 5.617977528089887

# %%
1e-1
# Out:
# 0.1

# %%
1./0.00245
# Out:
# 408.16326530612247
