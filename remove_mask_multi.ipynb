# %% [markdown]
# ## Imports

# %%
import cv2
import os
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ## Settings

# %%
src_dir = '/home/drevital/obstacles_classification_datasets/src_dec22_a/mask_train'
dst_dir = '/home/drevital/obstacles_classification_datasets/src_dec22_a/no_mask_train'
obs_src_dir = os.path.join(src_dir, 'obstacle')
#obs_src_dir = src_dir
no_obs_src_dir = os.path.join(src_dir, 'no_obstacle')
#no_obs_src_dir = src_dir
obs_dst_dir = os.path.join(dst_dir, 'obstacle')
#obs_dst_dir = dst_dir
no_obs_dst_dir = os.path.join(dst_dir, 'no_obstacle')
#no_obs_dst_dir = dst_dir

# %% [markdown]
# ## Function to remove mask images and store fixed image

# %%
def remove_masks(src_dir, dst_dir):
    im_fnames = os.listdir(src_dir)
    for im_fname in im_fnames:
        src_path = os.path.join(src_dir, im_fname)
        im = cv2.imread(src_path)
        #im = cv2.cvtColor(imrgb, cv2.COLOR_BGR2RGB)        
        w = im.shape[1]
        ref = im[:, :w//3]
        current = im[:, w//3:(w*2)//3] 
        mask = im[:, (w*2)//3:] 
        no_mask = cv2.hconcat([ref, current])
        dst_path = os.path.join(dst_dir, im_fname)
        print(f'dst_path: {dst_path}')
        cv2.imwrite(dst_path, no_mask)

# %%
remove_masks(obs_src_dir, obs_dst_dir)
remove_masks(no_obs_src_dir, no_obs_dst_dir)
# Out:
# dst_path: /home/drevital/obstacles_classification_datasets/src_dec22_a/no_mask_train/obstacle/2445_obstacles_classification_2022-10-25T07-36-59_0.16.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/src_dec22_a/no_mask_train/obstacle/1785_obstacles_classification_2022-10-25T07-36-56_0.11.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/src_dec22_a/no_mask_train/obstacle/2073_obstacles_classification_2022-10-25T07-36-57_0.03.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/src_dec22_a/no_mask_train/obstacle/2159_obstacles_classification_2022-10-25T07-36-58_0.31.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/src_dec22_a/no_mask_train/obstacle/1700_obstacles_classification_2022-10-25T07-36-56_0.18.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/src_dec22_a/no_mask_train/obstacle/2125_obstacles_classification_2022-10-25T07-36-57_0.17.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/src_dec22_a/no_mask_train/obstacle/2411_obstacles_classification_2022-10-25T07-36-59_0.30.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/src_dec22_a/no_mask_train/obstacle/1588_obstacles_classification_2022-10-25T07-36-55_0.09.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/src_dec22_a/no_mask_train/obstacle/1956_obstacles_classification_2022-10-25T07-36-57_0.12.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/src_dec22_a/no_mask_train/obstacle/1846_obstacles_classification_2022-10-25T07-36-56_0.21.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/src_dec22_a/no_mask_train/obstacle/1703_obstacles_classification_2022-10-25T07-36-56_0.15.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/src_dec22_a/no_mask_train/obstacle/2487_obstacles_classification_2022-10-25T07-36-59_0.30.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/src_dec22_a/no_mask_train/obstacle/2064_obstacles_classification_2022-10-25T07-36-57_0.05.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/src_dec22_a/no_mask_train/obstacle/1965_obstacles_classification_2022-10-25T07-36-57_0.25.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/src_dec22_a/no_mask_train/obstacle/1954_obstacles_classification_2022-10-25T07-36-57_0.09.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/src_dec22_a/no_mask_train/obstacle/2102_obstacles_classification_2022-10-25T07-36-57_0.07.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/src_dec22_a/no_mask_train/obstacle/2486_obstacles_classification_2022-10-25T07-36-59_0.17.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/src_dec22_a/no_mask_train/obstacle/2052_obstacles_classification_2022-10-25T07-36-57_0.21.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/src_dec22_a/no_mask_train/obstacle/1900_obstacles_classification_2022-10-25T07-36-57_0.29.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/src_dec22_a/no_mask_train/obstacle/2472_obstacles_classification_2022-10-25T07-36-59_0.27.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/src_dec22_a/no_mask_train/obstacle/1604_obstacles_classification_2022-10-25T07-36-55_0.05.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/src_dec22_a/no_mask_train/obstacle/1959_obstacles_classification_2022-10-25T07-36-57_0.13.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/src_dec22_a/no_mask_train/obstacle/1878_obstacles_classification_2022-10-25T07-36-56_0.07.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/src_dec22_a/no_mask_train/obstacle/1869_obstacles_classification_2022-10-25T07-36-56_0.05.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/src_dec22_a/no_mask_train/obstacle/1877_obstacles_classification_2022-10-25T07-36-56_0.21.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/src_dec22_a/no_mask_train/obstacle/1991_obstacles_classification_2022-10-25T07-36-57_0.02.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/src_dec22_a/no_mask_train/obstacle/1962_obstacles_classification_2022-10-25T07-36-57_0.12.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/src_dec22_a/no_mask_train/obstacle/1582_obstacles_classification_2022-10-25T07-36-55_0.08.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/src_dec22_a/no_mask_train/obstacle/1925_obstacles_classification_2022-10-25T07-36-57_0.07.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/src_dec22_a/no_mask_train/obstacle/2075_obstacles_classification_2022-10-25T07-36-57_0.03.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/src_dec22_a/no_mask_train/obstacle/1560_obstacles_classification_2022-10-25T07-36-55_0.05.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/src_dec22_a/no_mask_train/obstacle/2123_obstacles_classification_2022-10-25T07-36-57_0.24.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/src_dec22_a/no_mask_train/obstacle/2198_obstacles_classification_2022-10-25T07-36-58_0.26.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/src_dec22_a/no_mask_train/obstacle/2164_obstacles_classification_2022-10-25T07-36-58_0.18.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/src_dec22_a/no_mask_train/obstacle/2420_obstacles_classification_2022-10-25T07-36-59_0.31.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/src_dec22_a/no_mask_train/obstacle/2431_obstacles_classification_2022-10-25T07-36-59_0.06.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/src_dec22_a/no_mask_train/no_obstacle/2454_obstacles_classification_2022-10-25T07-36-59_0.65.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/src_dec22_a/no_mask_train/no_obstacle/2315_obstacles_classification_2022-10-25T07-36-58_0.69.jpg
