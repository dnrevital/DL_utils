# %% [markdown]
# ## Imports

# %%
import cv2
import os
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ## Settings

# %%
src_dir = '/home/drevital/obstacles_classification_datasets/kfs_jul22_b/mask_train'
dst_dir = '/home/drevital/obstacles_classification_datasets/kfs_jul22_b/no_mask_train'
obs_src_dir = os.path.join(src_dir, 'obstacle')
no_obs_src_dir = os.path.join(src_dir, 'no_obstacle')
obs_dst_dir = os.path.join(dst_dir, 'obstacle')
no_obs_dst_dir = os.path.join(dst_dir, 'no_obstacle')

# %% [markdown]
# ## Function to remove mask images and store fixed image

# %%
def remove_masks(src_dir, dst_dir):
    im_fnames = os.listdir(src_dir)
    for im_fname in im_fnames:
        src_path = os.path.join(src_dir, im_fname)
        im = cv2.imread(src_path)
        #im = cv2.cvtColor(imrgb, cv2.COLOR_BGR2RGB)        
        w = im.shape[1]
        ref = im[:, :w//3]
        current = im[:, w//3:(w*2)//3] 
        mask = im[:, (w*2)//3:] 
        no_mask = cv2.hconcat([ref, current])
        dst_path = os.path.join(dst_dir, im_fname)
        print(f'dst_path: {dst_path}')
        cv2.imwrite(dst_path, no_mask)

# %%
remove_masks(obs_src_dir, obs_dst_dir)
remove_masks(no_obs_src_dir, no_obs_dst_dir)
# Out:
# dst_path: /home/drevital/obstacles_classification_datasets/kfs_jul22_b/no_mask_train/obstacle/164_obstacles_classification_2022-07-11T08-13-39_0.69.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/kfs_jul22_b/no_mask_train/obstacle/134_obstacles_classification_2022-07-11T08-13-39_0.38.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/kfs_jul22_b/no_mask_train/obstacle/80_obstacles_classification_2022-07-11T08-13-39_0.63.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/kfs_jul22_b/no_mask_train/obstacle/516_obstacles_classification_2022-07-17T15-18-17_0.39.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/kfs_jul22_b/no_mask_train/obstacle/200_obstacles_classification_2022-07-11T09-49-11_0.50.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/kfs_jul22_b/no_mask_train/obstacle/20_obstacles_classification_2022-07-11T08-13-38_0.51.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/kfs_jul22_b/no_mask_train/obstacle/116_obstacles_classification_2022-07-17T15-18-16_0.48.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/kfs_jul22_b/no_mask_train/obstacle/313_obstacles_classification_2022-07-11T09-49-12_0.72.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/kfs_jul22_b/no_mask_train/obstacle/966_obstacles_classification_2022-07-11T09-49-16_0.74.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/kfs_jul22_b/no_mask_train/obstacle/47_obstacles_classification_2022-07-11T08-13-39_0.74.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/kfs_jul22_b/no_mask_train/obstacle/429_obstacles_classification_2022-07-11T09-49-13_0.72.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/kfs_jul22_b/no_mask_train/obstacle/524_obstacles_classification_2022-07-17T15-18-17_0.65.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/kfs_jul22_b/no_mask_train/obstacle/139_obstacles_classification_2022-07-11T08-13-39_0.41.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/kfs_jul22_b/no_mask_train/obstacle/210_obstacles_classification_2022-07-17T15-18-16_0.71.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/kfs_jul22_b/no_mask_train/no_obstacle/104_obstacles_classification_2022-07-17T15-18-57_0.57.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/kfs_jul22_b/no_mask_train/no_obstacle/115_obstacles_classification_2022-07-17T15-18-57_0.66.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/kfs_jul22_b/no_mask_train/no_obstacle/122_obstacles_classification_2022-07-17T15-18-57_0.47.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/kfs_jul22_b/no_mask_train/no_obstacle/110_obstacles_classification_2022-07-17T15-18-57_0.67.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/kfs_jul22_b/no_mask_train/no_obstacle/128_obstacles_classification_2022-07-17T15-18-57_0.44.jpg
# dst_path: /home/drevital/obstacles_classification_datasets/kfs_jul22_b/no_mask_train/no_obstacle/100_obstacles_classification_2022-07-17T15-18-57_0.58.jpg

# %%
20.95/11.76
# Out:
# 1.7814625850340136

# %%
10/1.78
# Out:
# 5.617977528089887

# %%
1e-1
# Out:
# 0.1

# %%
1./0.00245
# Out:
# 408.16326530612247
