# %%
import cv2

# %%
im = cv2.imread('170.png')

# %%
im.shape
# Out:
# (720, 1280, 3)

# %%
for i in range(im.shape[0]):
    print(f'sum of row {i}: {sum(im[i, :, 0])}')
# Out:
# sum of row 0: 248904
# sum of row 1: 248897
# sum of row 2: 248907
# sum of row 3: 248908
# sum of row 4: 248902
# sum of row 5: 248897
# sum of row 6: 248916
# sum of row 7: 248907
# sum of row 8: 248904
# sum of row 9: 248903
# sum of row 10: 248860
# sum of row 11: 248875
# sum of row 12: 248882
# sum of row 13: 248885
# sum of row 14: 248896
# sum of row 15: 248882
# sum of row 16: 248881
# sum of row 17: 248853
# sum of row 18: 248888
# sum of row 19: 248856
# sum of row 20: 248865
# sum of row 21: 248860
# sum of row 22: 248863
# sum of row 23: 248879
# sum of row 24: 248875
# sum of row 25: 248892
# sum of row 26: 248855
# sum of row 27: 248863
# sum of row 28: 248870
# sum of row 29: 248891
# sum of row 30: 248900
# sum of row 31: 248882
# sum of row 32: 248886
# sum of row 33: 248869
# sum of row 34: 248900
# sum of row 35: 248894
# sum of row 36: 248869
# sum of row 37: 248892
# sum of row 38: 248837
# sum of row 39: 248886
# sum of row 40: 248868
# sum of row 41: 248841
# ...

# %%
for i in range(im.shape[0]):
    s = sum(im[i])
    if sum(s) != 0:
        print(f'sum of row {i}: {sum(im[i])}')
# Out:
# sum of row 0: [72 72 72]
# sum of row 1: [65 65 65]
# sum of row 2: [75 75 75]
# sum of row 3: [76 76 76]
# sum of row 4: [70 70 70]
# sum of row 5: [65 65 65]
# sum of row 6: [84 84 84]
# sum of row 7: [75 75 75]
# sum of row 8: [72 72 72]
# sum of row 9: [71 71 71]
# sum of row 10: [28 28 28]
# sum of row 11: [43 43 43]
# sum of row 12: [50 50 50]
# sum of row 13: [53 53 53]
# sum of row 14: [64 64 64]
# sum of row 15: [50 50 50]
# sum of row 16: [49 49 49]
# sum of row 17: [21 21 21]
# sum of row 18: [56 56 56]
# sum of row 19: [24 24 24]
# sum of row 20: [33 33 33]
# sum of row 21: [28 28 28]
# sum of row 22: [31 31 31]
# sum of row 23: [47 47 47]
# sum of row 24: [43 43 43]
# sum of row 25: [60 60 60]
# sum of row 26: [23 23 23]
# sum of row 27: [31 31 31]
# sum of row 28: [38 38 38]
# sum of row 29: [59 59 59]
# sum of row 30: [68 68 68]
# sum of row 31: [50 50 50]
# sum of row 32: [54 54 54]
# sum of row 33: [37 37 37]
# sum of row 34: [68 68 68]
# sum of row 35: [62 62 62]
# ...

# %%
im[300][390:410]
# Out:
# array([[255, 255, 255],
#        [254, 254, 254],
#        [254, 254, 254],
#        [255, 255, 255],
#        [255, 255, 255],
#        [254, 254, 254],
#        [254, 254, 254],
#        [255, 255, 255],
#        [255, 255, 255],
#        [254, 254, 254],
#        [255, 255, 255],
#        [255, 255, 255],
#        [254, 254, 254],
#        [255, 255, 255],
#        [254, 254, 254],
#        [255, 255, 255],
#        [255, 255, 255],
#        [255, 255, 255],
#        [255, 255, 255],
#        [255, 255, 255]], dtype=uint8)

# %%
for j in range(im.shape[1]):
    print(f'sum of column {j}: {sum(im[:, j])}')
# Out:
# sum of column 0: [0 0 0]
# sum of column 1: [0 0 0]
# sum of column 2: [0 0 0]
# sum of column 3: [0 0 0]
# sum of column 4: [0 0 0]
# sum of column 5: [0 0 0]
# sum of column 6: [0 0 0]
# sum of column 7: [0 0 0]
# sum of column 8: [0 0 0]
# sum of column 9: [0 0 0]
# sum of column 10: [0 0 0]
# sum of column 11: [0 0 0]
# sum of column 12: [0 0 0]
# sum of column 13: [0 0 0]
# sum of column 14: [0 0 0]
# sum of column 15: [0 0 0]
# sum of column 16: [0 0 0]
# sum of column 17: [0 0 0]
# sum of column 18: [0 0 0]
# sum of column 19: [0 0 0]
# sum of column 20: [0 0 0]
# sum of column 21: [0 0 0]
# sum of column 22: [0 0 0]
# sum of column 23: [0 0 0]
# sum of column 24: [0 0 0]
# sum of column 25: [0 0 0]
# sum of column 26: [0 0 0]
# sum of column 27: [0 0 0]
# sum of column 28: [0 0 0]
# sum of column 29: [0 0 0]
# sum of column 30: [0 0 0]
# sum of column 31: [0 0 0]
# sum of column 32: [0 0 0]
# sum of column 33: [0 0 0]
# sum of column 34: [0 0 0]
# sum of column 35: [0 0 0]
# ...
