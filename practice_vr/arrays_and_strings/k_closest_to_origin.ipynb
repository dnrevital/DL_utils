# %% [markdown]
# Communication. Are you asking for requirements and clarity when necessary, or are you
# just diving into the code? Your initial tech screen should be a conversation, so don’t forget
# to ask questions.
#
#  Origin is [0][0]
#
# • Problem solving. We’re evaluating how you comprehend and explain complex ideas. Are
# you providing the reasoning behind a particular solution? Developing and comparing multiple
# solutions? Using appropriate data structures? Speaking about space and time complexity?
# Optimizing your solution?
#
#     The tricky part is how to come up with the k minimal (equivalently k maximal)
#     more efficiently than sorting which is NlogN
#
#     We can do with a list of length k.
#     Maintain max of list, with its index.
#     If next < max -- replace max with next.
#
# • Coding. Can you convert solutions to executable code? Is the code organized and does it
# capture the right logical structure?
#
# • Verification. Are you considering a reasonable number of test cases or coming up with a
# good argument for why your code is correct? If your solution has bugs, are you able to walk
# through your own logic to find them and explain what the code is doing?
# ======== Came with an alg that works,
# ======== Perfect coding for that
# ======= But -- alg isn't the optimal (self found this)

# %% [markdown]
# points = [[3,3],[5,-1],[-2,4]]
# k = 2
#
# size = 2
# max_dist sqrt(20)
#
# dist = sqrt(20)
# closest[sqrt(18), sqrt[26]] ==> pop(1) ==> closest[sqrt(18)] ==> closest[sqrt(18), sqrt(20]
# inds{sqrt(18): 0, sqrt(26): 1, sqrt(20): 1}

# %%
import heapq

def k_closest(points, k):
    dists = []
    val_points = {}
    size = 0
    
    for p in points:
        dist = p[0]**2 + p[1]**2
        val_points[dist] = p
        if size < k:
            heapq.heappush(dists, -dist)
        else:
            heapq.heappushpop(dists, -dist)
        size += 1
        
    closest = heapq.nsmallest(k, dists)
    return [val_points[-dist] for dist in closest]

# %%
points = [[3,3],[5,-1],[-2,4]]
k = 2
k_closest(points, k)
# Out:
# [[-2, 4], [3, 3]]

# %%
points = [[1,3],[-2,2]]
k = 1
k_closest(points, k)

# %%
k_closest(points, k)

# %%
import math

def k_closest_naive(points, k):
    size = 0
    max_dist = 0.0
    closest = []
    inds = {}
    
    for p in points:
        dist = math.sqrt(p[0]**2 + p[1]**2)
        if size < k:
            closest.append(p)
            inds[dist] = size
            if dist > max_dist:
                max_dist = dist
            size += 1
        else:
            if dist < max_dist:
                closest.pop(inds[max_dist])
                closest.append(p)
                inds[dist] = k-1
                max_dist = max(closest)
                
    return closest
