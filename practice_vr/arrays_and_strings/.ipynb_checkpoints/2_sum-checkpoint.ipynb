# %% [markdown]
# Communication. Are you asking for requirements and clarity when necessary, or are you
# just diving into the code? Your initial tech screen should be a conversation, so don’t forget
# to ask questions.
#
#    So I need to return 2 indices, right?
#
# • Problem solving. We’re evaluating how you comprehend and explain complex ideas. Are
# you providing the reasoning behind a particular solution? Developing and comparing multiple
# solutions? Using appropriate data structures? Speaking about space and time complexity?
# Optimizing your solution?
#
#   a + b = target
#
#   find a = target - b
#
#   Need the indices, so if I find one with this value, I know it has a counterpart,
#   which I need to know its index
#
#   So I can make a doctionary {value: index}, then I return [index of a=target-b which is HERE, index of a]
#
#   Complexity: N to ask for each (target-b) -- is it HERE?
#   Is it HERE is assumed O(1)
#
# • Coding. Can you convert solutions to executable code? Is the code organized and does it
# capture the right logical structure?
#
#     # Build the value to index doctionary
#
#     inds = {v: k for k,v in enumerate(nums)}
#
#     complement = [target-i for i in nums]
#
#     for i,c in enumerate(complement):
#         if c in nums:
#             return [i, inds[c]]
#
# • Verification. Are you considering a reasonable number of test cases or coming up with a
# good argument for why your code is correct? If your solution has bugs, are you able to walk
# through your own logic to find them and explain what the code is doing?
#
# ======= VERY GOOD
#
# ========= Although I did it before -- did not jump into, succeeded to analyze by heart
#
# ====== Went over the code BY HEART -- found a problem and fixed it, before 1st run
#
#         (Had to reurn inds[taget-c], inds[c]], initially wrote [i, inds[c]] which is wrong

# %%
def two_sum(nums, target):
    inds = {v: k for k,v in enumerate(nums)}    
    complement = [target-n for n in nums]
    
    for i,c in enumerate(complement):
        if c in nums:
            return [inds[target-c], inds[c]]

# %%
# [7, 2, -2, -6]

# %%
nums = [2,7,11,15]
target = 26
two_sum(nums, target)
# Out:
# [2, 3]
