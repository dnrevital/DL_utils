# %% [markdown]
# Communication. Are you asking for requirements and clarity when necessary, or are you
# just diving into the code? Your initial tech screen should be a conversation, so don’t forget
# to ask questions.
#
#     rec1 = [0,0,2,2], rec2 = [1,1,3,3]
#
#     True/False whether they overlap
#
#     overlap =  TL between other's TL/BR  --OR-- BR between other's TL/BR
#
#     Between = x between and y between
#
#     Code:
#
#         tl_overlap = rec2[0] >= rec1[0] and rec2[1] >= rec1[1]
#         br_overlap = rec2[2] >= rec1[2] and rec2[3] >= rec1[3]
#
#         return tl_overlap or br_overlap
#
# • Problem solving. We’re evaluating how you comprehend and explain complex ideas. Are
# you providing the reasoning behind a particular solution? Developing and comparing multiple
# solutions? Using appropriate data structures? Speaking about space and time complexity?
# Optimizing your solution?
#
# • Coding. Can you convert solutions to executable code? Is the code organized and does it
# capture the right logical structure?
#
# • Verification. Are you considering a reasonable number of test cases or coming up with a
# good argument for why your code is correct? If your solution has bugs, are you able to walk
# through your own logic to find them and explain what the code is doing?
#
# == GOOD == Principle for right alg
# == GOOD == tested on correct edge cases, but not verbally
#
# == NO GOOD == Basic alg mistakes, catch after trials
#
#         Need better verbal debugging -- such a thing -- for ALL combs of TL/BR/OVERLAP
#         Need better verabl debuggin anyway to avoid mistakes with
#                using rect1 vs. rect2 and the like !!

# %% [markdown]
# rec1 = [0,0,2,2]
# rec2 = [1,1,3,3]
#
# tl_overlap = true and true = true
# br_overlap = false
#
# true

# %%
def overlap(rec1, rec2):
    tl_overlap = (rec2[0] >= rec1[0]) and\
                 (rec2[1] >= rec1[1]) and\
                 (rec2[0] < rec1[2])  and\
                 (rec2[1] < rec1[3])
    br_overlap = (rec2[2] > rec1[0])  and\
                 (rec2[3] > rec1[1])  and\
                 (rec2[2] <= rec1[2]) and\
                 (rec2[3] <= rec1[3])

    return (tl_overlap or br_overlap)

# %%
rec1 = [0,0,1,1]
rec2 = [1,1,2,2]
overlap(rec1, rec2)
# Out:
# False
