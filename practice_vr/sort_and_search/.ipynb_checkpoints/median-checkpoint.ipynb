# %% [markdown]
# Communication. Are you asking for requirements and clarity when necessary, or are you
# just diving into the code? Your initial tech screen should be a conversation, so don’t forget
# to ask questions.
#
#     Req's -- I guess they are different sizes?
#
#     Time Complexity
#
#         O(log(m+n))
#
#         x x x x x x x
#           y y y y y
#
#           1 2 3 7 8 9
#               4 5 6
# • Problem solving. We’re evaluating how you comprehend and explain complex ideas. Are
# you providing the reasoning behind a particular solution? Developing and comparing multiple
# solutions? Using appropriate data structures? Speaking about space and time complexity?
# Optimizing your solution?
#
#     Naive is m+n to find index (m+n)/2
#
#     We can easily take index m/2, n/2, median is not before any in the 1st and 2nd
#
#
#
# • Coding. Can you convert solutions to executable code? Is the code organized and does it
# capture the right logical structure?
#
#     # Search the mediam element -- index (m+n)/2
#     initiate cur_ind as m//2
#     target_ind is (m+n)/2
#     initiate cur as nums1[cur_ind]
#
#     import sys
#
#     m = len(nums1)
#     n = len(nums2)
#
#     cur_ind = m//2
#     nums1_median_ind = cur_ind
#     nums1_cur_ind = cur_ind
#     median_ind = (m+n)//2
#     cur = nums1[cur_ind]
#     median_arr = None
#
#     if cur_ind < median_ind-1:
#         for cur, ind in enumerate(nums1[nums1_median_ind:):
#             nums2_ind = bisect_left(nums2, cur)
#             cur_ind = nums1_median_ind + nums2_ind
#             if cur_ind == median_ind-1:
#                 median_arr = num1
#                 break
#             elif cur_ind == median_ind:
#                 median_arr = nums2
#                 break
#
#     elif cur_ind > median_ind:
#         for cur, ind in enumerate(nums1[-1::-1]):
#             nums2_ind = bisect_left(nums2, cur)
#             cur_ind = nums1_median_ind + nums_ind
#             if cur_ind == median_ind-1:
#                 median_arr = num1
#                 break
#             elif cur_ind == median_ind:
#                 median_arr = nums2
#                 break
#
#     if median_arr == nums1:
#         median = cur
#     else:
#         median = nums2[cur_ind-1]
#
#     even = (m+n)%2 == 0
#
#     if even:
#         n1, n2 = sys.maxsize, sys.maxsize
#         if ind < m-1:
#             n1 = nums1[ind+1]
#         if nums2_ind < n-1:
#             n2 = nums2[nums2_ind + 1]
#         next = min(n1, n2)
#         median = (median + next) / 2
#
#     return median
#
# • Verification. Are you considering a reasonable number of test cases or coming up with a
# good argument for why your code is correct? If your solution has bugs, are you able to walk
# through your own logic to find them and explain what the code is doing?
#
# TOO LONG, GOT A NICE IDEA, YET NOT WORKING, MUST CHECK WHY AND RESOLVE !!

# %%
import sys
from bisect import bisect_left

# %% [markdown]
# nums1 = [1, 2]
# num2 = [2]
#
# m=2
# n=1
# median_ind = 1
#
# cur_m = nums1[1] = 2
# cur_n = nums2[0] = 2
#
# m_ind = bisect_left(2, [1,2]) = 1
# n_ind = bisect_left(2, [2]) = 0
#
# m_gap = median_ind - (n//2 + m_ind) = 1 - 1 = 0
# n_gap = median_ind - (m//2 + n_ind) = 1 - 1 = 0
#
# m_edge = max(0, m_ind + m_gap) = 1
# m_edge = min(m_edge, m-1) = 1
# n_edge = max(0, n_ind + n_gap) = 0
# n_edge = min(n_edge, n-1) = 0
#
# new_nums1 = nums1[min(m_ind, m_edge):max(m_ind, m_edge)] = nums1[1:1]
# new_nums2 = nums2[min(n_ind, n_edge):max(n_ind, n_edge)] = nums2[0:1]

# %%
def parity_median(nums1, nums2, even):
    m = len(nums1)
    n = len(nums2)
    median_ind = (m+n)//2
    
    if m==1 and n==1:
        if even:
            return (nums1[0]+nums2[0])/2
        else:
            return min(nums1[0], nums2[0])
    
    cur_m = nums1[m//2]
    cur_n = nums2[n//2]
    
    m_ind = bisect_left(nums1, cur_n)
    n_ind = bisect_left(nums2, cur_m)
    
    m_gap = median_ind - (n//2 + m_ind)
    n_gap = median_ind - (m//2 + n_ind)
    
    m_edge = max(0, m_ind + m_gap)
    m_edge = min(m_edge, m-1)
    n_edge = max(0, n_ind + n_gap)
    n_edge = min(n_edge, n-1)
    
    new_nums1 = nums1
    new_nums2 = nums2
    
    new_nums1 = nums1[min(m_ind, m_edge):max(m_ind, m_edge)]
    if len(new_nums1) == 0:
        new_nums1 = [nums1[min(m_ind, m_edge)]]
    new_nums2 = nums2[min(n_ind, n_edge):max(n_ind, n_edge)]
    if len(new_nums2) == 0:
        new_nums2 = [nums2[min(n_ind, n_edge)]]
    
    return parity_median(new_nums1, new_nums2, even)

# %% [markdown]
# nums1 = [1, 2]
# num2 = [2]

# %%
def median(nums1, nums2):
    m = len(nums1)
    n = len(nums2)
    even = (m+n) % 2 == 0
    
    return parity_median(nums1, nums2, even)

# %%
nums1 = [1, 2, 3, 7, 8, 9]
nums2 = [4, 5, 6]
median(nums1, nums2)
# Out:
# 6
