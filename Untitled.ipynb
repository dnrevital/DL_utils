# %%
import os
import cv2
import matplotlib.pyplot as plt

# %%
folder = '/home/drevital/obstacles_classification_datasets/gg_2_channels/eval/obstacle'
imname = '1_202_.99_2021-08-15--18-13-38_.jpg'
impath = os.path.join(folder, imname)

# %%
im = cv2.imread(impath)
plt.imshow(im)
plt.show()
