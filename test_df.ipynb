# %%
import os
import pandas as pd

# %%
df_dir = '/home/drevital/obstacles_classification_datasets/test2'
df_name = 'test2.csv'
df_path = os.path.join(df_dir, df_name)
imname = '327_obstacles_classification_2022-06-27T08-37-14_0.75_unknown_noobs_1.0000_.jpg'

# %%
df = pd.read_csv(df_path)

# %%
df.head()
# Out:
#    Unnamed: 0                                            in_name  \
# 0           0  327_obstacles_classification_2022-06-27T08-37-...
# 1           1  2_obstacles_classification_2022-06-27T08-37-13...
# 2           2  8_obstacles_classification_2022-06-27T08-37-13...
# 3           3  3_obstacles_classification_2022-06-27T08-37-13...
# 4           4  1_obstacles_classification_2022-06-27T08-37-03...
#
#                                             out_name   class_name  \
# 0  327_obstacles_classification_2022-06-27T08-37-...  no_obstacle
# 1  2_obstacles_classification_2022-06-27T08-37-13...     obstacle
# 2  8_obstacles_classification_2022-06-27T08-37-13...     obstacle
# 3  3_obstacles_classification_2022-06-27T08-37-13...     obstacle
# 4  1_obstacles_classification_2022-06-27T08-37-03...     obstacle
#
#    diff_metric     diff_coef  sample_weight
# 0     0.000000  1.164597e-11       1.000000
# 1     0.026250  1.000000e+00       2.500000
# ...

# %%
row = df.loc[df['out_name'] == imname]

# %%
row
# Out:
#    Unnamed: 0                                            in_name  \
# 0           0  327_obstacles_classification_2022-06-27T08-37-...
#
#                                             out_name   class_name  \
# 0  327_obstacles_classification_2022-06-27T08-37-...  no_obstacle
#
#    diff_metric     diff_coef  sample_weight
# 0          0.0  1.164597e-11            1.0

# %%
row['class_name'][0]
# Out:
# 'no_obstacle'

# %%
row['sample_weight'][0]
# Out:
# 1.000000000017469

# %%
type(row['sample_weight'][0])
# Out:
# numpy.float64

# %%
row['class_name'].values[0]
# Out:
# 'no_obstacle'

# %%
row['sample_weight'].values[0]
# Out:
# 1.000000000017469
