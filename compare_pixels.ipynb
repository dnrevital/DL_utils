# %% [markdown]
# ## Imports

# %%
import numpy as np
import os

# %% [markdown]
# ## Settings

# %%
load_dir = '/home/drevital/obstacles_classification_datasets/tst_imags'

# %% [markdown]
# ## Load image tensors & comapre

# %%
im1_trt = np.load(os.path.join(load_dir, 'im1_trt.npy'))
im1_tf = np.load(os.path.join(load_dir, 'im1_tf.npy'))

# %%
im1_trt.shape, im1_tf.shape
# Out:
# ((200, 200, 3), (200, 200, 3))

# %%
im1_trt[100][97:102]
# Out:
# array([[0.3764706 , 0.39215687, 0.40392157],
#        [0.3764706 , 0.39215687, 0.40392157],
#        [0.3764706 , 0.39215687, 0.40392157],
#        [0.3764706 , 0.39215687, 0.40392157],
#        [0.7058824 , 0.72156864, 0.73333335]], dtype=float32)

# %%
im1_tf[100][97:102]
# Out:
# array([[0.3764706 , 0.39215687, 0.40392157],
#        [0.3764706 , 0.39215687, 0.40392157],
#        [0.3764706 , 0.39215687, 0.40392157],
#        [0.7058824 , 0.72156864, 0.73333335],
#        [0.7058824 , 0.72156864, 0.73333335]], dtype=float32)

# %%
np.array_equal(im1_trt, im1_tf)
# Out:
# False

# %%
np.sum(np.absolute(im1_trt - im1_tf)) / (200*200*3)
# Out:
# 0.01320938008626302

# %%
np.sum(np.absolute(im1_trt[100][:10] - im1_tf[100][:10]))
# Out:
# 0.02352941

# %%
im1_trt[0].shape
# Out:
# (200, 3)
