# %% [markdown]
# ## Imports

# %%
import numpy as np
import os

# %% [markdown]
# ## Settings

# %%
load_dir = '/home/drevital/obstacles_classification_datasets/tst_imags'

# %% [markdown]
# ## Load image tensors & comapre

# %%
im1_trt = np.load(os.path.join(load_dir, 'open_im1_trt.npy'))
im1_tf = np.load(os.path.join(load_dir, 'open_im1_tf.npy'))

# %%
im1_trt.shape, im1_tf.shape
# Out:
# ((200, 600, 3), (200, 600, 3))

# %%
im1_trt[102][98:101]
# Out:
# array([[103, 152, 198],
#        [104, 153, 199],
#        [105, 153, 201]], dtype=uint8)

# %%
im1_tf[102][98:101]
# Out:
# array([[198., 151., 105.],
#        [199., 153., 104.],
#        [200., 154., 105.]], dtype=float32)

# %%
np.array_equal(im1_trt, im1_tf)
# Out:
# False

# %%
np.sum(np.absolute(im1_trt - im1_tf)) / (200*200*3)
# Out:
# 56.615675

# %%
np.sum(np.absolute(im1_trt[100][:10] - im1_tf[100][:10]))
# Out:
# 747.0

# %%
im1_trt[0].shape
# Out:
# (600, 3)
