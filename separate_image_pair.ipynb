# %% [markdown]
# ## Imports

# %%
import os
import numpy as np
import cv2

# %% [markdown]
# ## Settings

# %%
imdir = '/home/drevital/cs_video_processor/debug_images/test_docker/classified_obstacle'
imname = '1_252_.89_2021-08-03--17-22-32_.jpg'
outdir = '/home/drevital/obstacles_classification_model'
img_height = 200
img_width = 200

# %% [markdown]
# ## Main

# %%
imrgb = cv2.imread(os.path.join(imdir, imname))
im = cv2.cvtColor(imrgb, cv2.COLOR_BGR2GRAY)  
w = im.shape[1]
im1 = im[:,:w//2]
im2 = im[:,w//2:]    
outpath1 = os.path.join(outdir, 'im3.jpg')
outpath2 = os.path.join(outdir, 'im4.jpg')
cv2.imwrite(outpath1, im1)
cv2.imwrite(outpath2, im2)
# Out:
# True

# %%
imrgb.shape
# Out:
# (84, 166, 3)

# %%
im.shape
# Out:
# (84, 166)

# %%
type(im)
# Out:
# numpy.ndarray

# %%
len(im1[0].tolist())
# Out:
# 83
